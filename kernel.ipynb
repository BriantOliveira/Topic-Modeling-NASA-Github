# %%
import bq_helper
from bq_helper import BigQueryHelper
library = bq_helper.BigQueryHelper(active_project="bigquery-public-data",
                                   dataset_name="libraries_io")

# %%
bq_assistant = BigQueryHelper("bigquery-public-data", "libraries_io")
bq_assistant.list_tables()
# Out:
# ['dependencies',
#  'projects',
#  'projects_with_repository_fields',
#  'repositories',
#  'repository_dependencies',
#  'tags',
#  'versions']

# %%
bq_assistant.head("repositories", num_rows=20)
# Out:
#           id host_type                        name_with_owner  \
# 0   20677090    GitLab                        SungGeun/sample
# 1   32572190    GitHub                victorbasset/INFO802-TP
# 2   32875848    GitHub        assemmohamedali/data-structures
# 3    3476797    GitHub        kevinlu1211/chinese-pinyin-JSON
# 4    9832518    GitHub  xujianhai/netease_cross_platform_demo
# 5   10801387    GitHub           YanaPlotnikova/bootstrapcats
# 6   25419311    GitHub                            sikaapp/api
# 7   29126473    GitHub                kennygrant/wilfred-owen
# 8    6536748    GitHub                      getupcloud/flower
# 9    3350485    GitHub                 HackToday/codelauncher
# 10  20183150    GitHub                     lodacom/UpYourMood
# 11  24663166    GitHub                   123biswash/BootCamp1
# 12  16845399    GitHub              ry-tk-br/sotsuron_1322009
# 13  22769428    GitHub                       colinsher/taylor
# 14  12772950    GitHub                          kreiz0/godota
# 15  27262250    GitHub               B-ooleanTrue/Bon-Appetit
# 16  26189388    GitHub             alainwest/Lorem-repository
# 17  10088248    GitHub          AZMAG/map-DemographicRegional
# 18   5477989    GitHub               timfel/ruby_image_viewer
# 19  19612807    GitHub      imann24/parallel-computing-csc352
#
#                                           description   fork  \
# 0                                                       True
# 1                                                      False
# 2                            many application and ADT  False
# 3                                                      False
# 4   use Electron to build cross-platform  fake net...  False
# 5                                                      False
# 6                                            SIKA API  False
# 7                           War poems by Wilfred Owen  False
# 8   Real-time monitor and web admin for Celery dis...   True
# 9   A Flask Python server to launch C code and Pyt...   True
# 10                                                     False
# 11                                                     False
# 12                                                     False
# 13                                                     False
# 14                                                     False
# 15                                         Bonfire :D  False
# 16                                                     False
# 17  MAG Regional demographics map viewer for selec...  False
# 18                                                     False
# 19                                                     False
#
#            created_timestamp         updated_timestamp  \
# 0  2016-01-05 07:35:28+00:00 2016-01-05 07:57:48+00:00
# 1  2018-02-03 10:58:19+00:00 2018-02-03 10:58:22+00:00
# 2  2017-11-16 14:58:02+00:00 2018-02-18 12:03:34+00:00
# 3  2015-11-23 03:45:59+00:00 2017-04-28 23:03:33+00:00
# 4  2016-05-02 11:31:34+00:00 2017-12-25 22:26:07+00:00
# 5  2016-06-07 14:07:27+00:00 2018-02-06 18:23:51+00:00
# 6  2017-06-23 09:58:16+00:00 2017-06-23 09:59:04+00:00
# 7  2017-10-09 11:13:48+00:00 2017-10-10 00:52:16+00:00
# 8  2015-03-30 21:44:23+00:00 2017-05-03 20:03:08+00:00
# 9  2015-05-05 04:51:53+00:00 2015-11-18 10:23:27+00:00
# 10 2013-10-01 08:58:57+00:00 2017-02-14 08:03:33+00:00
# 11 2017-05-25 19:48:24+00:00 2017-05-25 21:16:17+00:00
# 12 2016-12-10 08:37:20+00:00 2017-03-05 07:20:56+00:00
# 13 2017-04-04 22:11:51+00:00 2017-04-05 02:12:35+00:00
# 14 2016-08-20 16:59:11+00:00 2017-06-01 13:01:45+00:00
# 15 2017-08-12 03:35:58+00:00 2017-08-12 03:50:09+00:00
# 16 2017-07-17 09:08:59+00:00 2017-07-17 09:08:59+00:00
# 17 2016-05-11 18:30:56+00:00 2017-11-15 05:22:45+00:00
# 18 2014-04-05 11:05:03+00:00 2017-09-29 18:00:50+00:00
# 19 2017-02-02 19:22:48+00:00 2018-02-16 13:02:36+00:00
#
#        last_pushed_timestamp                        homepage_url     size  \
# 0                        NaT                                          NaN
# 1  2018-02-03 10:58:20+00:00                                          0.0
# 2  2017-12-21 12:13:36+00:00                                          0.0
# 3  2015-11-23 04:05:54+00:00                                       4483.0
# 4  2016-05-02 11:32:11+00:00                                       1312.0
# 5  2016-06-07 14:07:27+00:00                                          0.0
# 6  2017-06-23 09:58:17+00:00                 https://api.sika.io      0.0
# 7  2017-10-09 16:29:46+00:00                                        372.0
# 8  2015-03-30 22:27:07+00:00       http://flower.readthedocs.org   2742.0
# 9  2015-05-05 05:30:51+00:00                                        305.0
# 10 2013-12-12 17:17:43+00:00                                      25196.0
# 11 2017-05-25 19:50:17+00:00                                          1.0
# 12 2016-12-10 08:47:06+00:00                                          0.0
# 13 2017-04-04 22:25:43+00:00  http://www.colinsherman.com/taylor      5.0
# 14 2016-08-26 10:40:42+00:00                                        207.0
# 15 2017-08-12 03:37:25+00:00                                          0.0
# 16 2017-07-17 09:09:00+00:00                                          0.0
# 17 2017-08-03 20:41:42+00:00                                         13.0
# 18 2014-04-22 12:47:07+00:00                                       2384.0
# 19 2017-02-02 19:22:48+00:00                                          0.0
#
#     ...  security_audit_filename status     last_synced_timestamp  sourcerank  \
# 0   ...                        f        2017-05-20 03:27:08+00:00           2
# 1   ...                                 2018-02-03 10:58:22+00:00           1
# 2   ...                                                       NaT           1
# 3   ...                                                       NaT           2
# 4   ...                                 2016-05-02 11:31:39+00:00           1
# 5   ...                                 2016-06-07 14:09:43+00:00           1
# 6   ...                                 2017-06-23 09:59:04+00:00           2
# 7   ...                                 2017-10-10 00:52:15+00:00           2
# 8   ...                                                       NaT           4
# 9   ...                                                       NaT           0
# 10  ...                                 2017-02-14 08:03:32+00:00           1
# 11  ...                                 2017-05-25 21:16:17+00:00           1
# 12  ...                                 2017-03-05 07:20:56+00:00           1
# 13  ...                                 2017-04-05 02:12:34+00:00           2
# 14  ...                                 2016-08-21 11:29:28+00:00           0
# 15  ...                                 2017-08-12 03:50:05+00:00           1
# 16  ...                                 2017-07-17 09:09:15+00:00           1
# 17  ...                                 2016-05-11 18:31:03+00:00           4
# 18  ...                                                       NaT           2
# 19  ...                                 2017-02-02 19:22:56+00:00           1
#
#    display_name  scm_type pull_requests_enabled  logo_url keywords  an
# 0        GitLab                             git         t
# 1        GitHub                             git
# 2        GitHub                             git
# 3        GitHub
# 4        GitHub                             git
# 5        GitHub
# 6        GitHub
# 7        GitHub                             git
# 8        GitHub
# 9        GitHub
# 10       GitHub
# 11       GitHub
# 12       GitHub
# 13       GitHub
# 14       GitHub
# 15       GitHub                             git
# 16       GitHub
# 17       GitHub                             git
# 18       GitHub
# 19       GitHub
#
# [20 rows x 40 columns]

# %%
bq_assistant.table_schema("repositories")
# Out:
#                                 name       type      mode  \
# 0                                 id    INTEGER  NULLABLE
# 1                          host_type     STRING  NULLABLE
# 2                    name_with_owner     STRING  NULLABLE
# 3                        description     STRING  NULLABLE
# 4                               fork    BOOLEAN  NULLABLE
# 5                  created_timestamp  TIMESTAMP  NULLABLE
# 6                  updated_timestamp  TIMESTAMP  NULLABLE
# 7              last_pushed_timestamp  TIMESTAMP  NULLABLE
# 8                       homepage_url     STRING  NULLABLE
# 9                               size    INTEGER  NULLABLE
# 10                       stars_count    INTEGER  NULLABLE
# 11                          language     STRING  NULLABLE
# 12                    issues_enabled    BOOLEAN  NULLABLE
# 13                      wiki_enabled    BOOLEAN  NULLABLE
# 14                     pages_enabled    BOOLEAN  NULLABLE
# 15                       forks_count    INTEGER  NULLABLE
# 16                        mirror_url     STRING  NULLABLE
# 17                 open_issues_count    INTEGER  NULLABLE
# 18                    default_branch     STRING  NULLABLE
# 19                    watchers_count    INTEGER  NULLABLE
# 20                              uuid     STRING  NULLABLE
# 21       fork_source_name_with_owner     STRING  NULLABLE
# 22                           license     STRING  NULLABLE
# 23                contributors_count    INTEGER  NULLABLE
# 24                   readme_filename     STRING  NULLABLE
# 25                changelog_filename     STRING  NULLABLE
# 26  contributing_guidelines_filename     STRING  NULLABLE
# 27                  license_filename     STRING  NULLABLE
# 28          code_of_conduct_filename     STRING  NULLABLE
# 29    security_threat_model_filename     STRING  NULLABLE
# 30           security_audit_filename     STRING  NULLABLE
# 31                            status     STRING  NULLABLE
# 32             last_synced_timestamp  TIMESTAMP  NULLABLE
# 33                        sourcerank    INTEGER  NULLABLE
# 34                      display_name     STRING  NULLABLE
# 35                          scm_type     STRING  NULLABLE
# 36             pull_requests_enabled     STRING  NULLABLE
# 37                          logo_url     STRING  NULLABLE
# 38                          keywords     STRING  NULLABLE
# 39                                an     STRING  NULLABLE
#
#                                           description
# 0   he unique primary key of the repository in the...
# 1   Which website the repository is hosted on, eit...
# 2   The repository name and owner seperated by a s...
# 3                          Description of repository.
# 4                Is the repository a fork of another.
# 5   Timestamp of when the repository was created o...
# 6   Timestamp of when the repository was last save...
# 7   Timestamp of when the repository was last push...
# 8   URL of a declared homepage or other website fo...
# 9   Size of the repository in kilobytes, only avai...
# 10  Number of stars on the repository, only availa...
# 11  Primary programming language the project is wr...
# 12   Is the bug tracker enabled for this repository?.
# 13          Is the wiki enabled for this repository?.
# 14  Is GitHub pages enabled for this repository? o...
# 15                Number of forks of this repository.
# 16  URL of the repositroy of which this is a mirro...
# 17  Number of open issues on the repository bug tr...
# 18                  Primary branch of the repository.
# 19  Number of subscribers to all notifications for...
# 20  ID of the repository on the remote host, not u...
# 21  If the repository is a fork, the repository na...
# 22  SPDX identifier of the license of the reposito...
# 23  Number of unique contributors that have commit...
# 24  If a readme file has been detected, the full n...
# 25  If a changelog file has been detected, the ful...
# 26  If a contributing guidelines file has been det...
# 27  If a license file has been detected, the full ...
# 28  If a code of conduct file has been detected, t...
# 29  If a Security Threat Model file has been detec...
# 30  If a Security Audit file has been detected, th...
# 31  Either Active, Deprecated, Unmaintained, Help ...
# 32  Timestamp of when Libraries.io last synced the...
# 33  Libraries.io defined score based on quality, p...
# 34  Display name for the repository, only availabl...
# 35  Type of source control repository uses, always...
# 36  Are pull requests enabled for this repository?...
# 37  Custom logo url for repository, only available...
# 38  Comma separated array of keywords, called "top...
# 39

# %% [markdown]
# What are the repositories, avg project size, and avg # of stars?

# %%
query1 = """
SELECT
  host_type,
  COUNT(*) repositories,
  ROUND(AVG(size),2) avg_size,
  ROUND(AVG(stars_count),2) avg_stars
FROM
  `bigquery-public-data.libraries_io.repositories`
GROUP BY
  host_type
ORDER BY
  repositories DESC
LIMIT
  1000;
        """
response1 = library.query_to_pandas_safe(query1)
response1.head(10)
# Out:
#    host_type  repositories  avg_size  avg_stars
# 0     GitHub      30238391   6165.09       3.18
# 1  Bitbucket        252305  16029.57       0.00
# 2     GitLab        214938   5367.22       0.05

# %% [markdown]
# What are the top dependencies per platform?

# %%
query2 = """
SELECT
  dependency_platform,
  COUNT(*) dependencies,
  APPROX_TOP_COUNT(dependency_name, 3) top_dependencies
FROM
  `bigquery-public-data.libraries_io.dependencies`
GROUP BY
  dependency_platform
ORDER BY
  dependencies DESC;
        """
response2 = library.query_to_pandas_safe(query2, max_gb_scanned=10)
response2.head(20)
# Out:
#    dependency_platform  dependencies  \
# 0                  NPM      52886648
# 1             Rubygems       4487068
# 2            Packagist       4178018
# 3                Maven       3592035
# 4                NuGet       3097656
# 5                 CPAN       2406593
# 6                Cargo        350862
# 7                 CRAN        277856
# 8                  Npm        215433
# 9                 Pypi        126535
# 10                 Pub        119810
# 11              Puppet         57292
# 12                 Hex         50227
# 13                 Elm         16450
# 14                 Dub         11410
# 15             Haxelib          5776
# 16            Homebrew          4886
#
#                                      top_dependencies
# 0   [{'value': 'mocha', 'count': 1129627}, {'value...
# 1   [{'value': 'rake', 'count': 366136}, {'value':...
# 2   [{'value': 'phpunit/phpunit', 'count': 332742}...
# 3   [{'value': 'junit:junit', 'count': 156591}, {'...
# 4   [{'value': 'Newtonsoft.Json', 'count': 165805}...
# 5   [{'value': 'Test-More', 'count': 139176}, {'va...
# 6   [{'value': 'serde', 'count': 13800}, {'value':...
# 7   [{'value': 'R', 'count': 43374}, {'value': 'st...
# 8   [{'value': 'atom-space-pen-views', 'count': 12...
# 9   [{'value': 'requests', 'count': 7999}, {'value...
# 10  [{'value': 'unittest', 'count': 9677}, {'value...
# 11  [{'value': 'puppetlabs-stdlib', 'count': 16516...
# 12  [{'value': 'poison', 'count': 6552}, {'value':...
# 13  [{'value': 'elm-lang/core', 'count': 5634}, {'...
# 14  [{'value': 'vibe-d', 'count': 606}, {'value': ...
# 15  [{'value': 'openfl', 'count': 442}, {'value': ...
# 16  [{'value': 'Pkg-config', 'count': 454}, {'valu...

# %% [markdown]
# What are the top unmaintained or deprecated projects?

# %%
query3 = """
SELECT
  name,
  repository_sourcerank,
  LANGUAGE,
  status
FROM
  `bigquery-public-data.libraries_io.projects_with_repository_fields`
WHERE
  status IN ('Deprecated',
    'Unmaintained')
ORDER BY
  repository_sourcerank DESC
LIMIT
  20;
        """
response3 = library.query_to_pandas_safe(query3, max_gb_scanned=10)
response3.head(20)
# Out:
#                                          name  repository_sourcerank  \
# 0                          react-linked-input                     27
# 1       org.eclipse.jetty:jetty-documentation                     22
# 2                   external-react-hot-loader                     22
# 3                                       spree                     20
# 4                  pouchdb-abstract-mapreduce                     19
# 5                           pouchdb-mapreduce                     19
# 6                                        jade                     18
# 7                                    unittest                     18
# 8                                        jscs                     16
# 9                         akavache.deprecated                     16
# 10                                  scss-lint                     16
# 11                                   edp-jscs                     16
# 12                                      jscs2                     16
# 13                           facebook/php-sdk                     16
# 14                                    wiredep                     16
# 15                                     nomnom                     15
# 16                                   html5lib                     15
# 17  org.igniterealtime.smack:smack-jingle-old                     15
# 18                        tidepool-data-model                     15
# 19      org.igniterealtime.smack:smack-jingle                     15
#
#       LANGUAGE        status
# 0   JavaScript  Unmaintained
# 1         Java    Deprecated
# 2   JavaScript    Deprecated
# 3         Ruby    Deprecated
# 4   JavaScript    Deprecated
# 5   JavaScript    Deprecated
# 6   JavaScript    Deprecated
# 7         Dart    Deprecated
# 8   JavaScript    Deprecated
# 9           C#    Deprecated
# 10        Ruby    Deprecated
# 11  JavaScript    Deprecated
# 12  JavaScript    Deprecated
# 13         PHP    Deprecated
# 14  JavaScript  Unmaintained
# 15              Unmaintained
# 16        Dart    Deprecated
# 17        Java  Unmaintained
# 18                Deprecated
# 19        Java  Unmaintained

# %% [markdown]
# Credit: Many functions are adapted from https://console.cloud.google.com/marketplace/details/libraries-io/librariesio

# %%
import requests 

r = requests.get('https://libraries.io/api/github/nasa/repositories?api_key=91f3f771438b366da564093e002a2c61&per_page=200')
project_names = r.json()
names = list(map(lambda x: x['full_name'], project_names))
names
# Out:
# ['nasa/openmct',
#  'nasa/NASA-3D-Resources',
#  'nasa/mct',
#  'nasa/earthdata-search',
#  'nasa/trick',
#  'nasa/isle',
#  'nasa/api-docs',
#  'nasa/VICAR',
#  'nasa/code-nasa-gov',
#  'nasa/XPlaneConnect',
#  'nasa/apod-api',
#  'nasa/Open-Source-Catalog',
#  'nasa/osal',
#  'nasa/nasa-latex-docs',
#  'nasa/CrisisMappingToolkit',
#  'nasa/NASTRAN-95',
#  'nasa/QuIP',
#  'nasa/T-MATS',
#  'nasa/DERT',
#  'nasa/autodoc',
#  'nasa/pvslib',
#  'nasa/CFL3D',
#  'nasa/Common-Metadata-Repository',
#  'nasa/Kodiak',
#  'nasa/OpenSPIFe',
#  'nasa/kepler-pipeline',
#  'nasa/icarous',
#  'nasa/RHEAS',
#  'nasa/IDF',
#  'nasa/PyTDA',
#  'nasa/fprime',
#  'nasa/ipv6_python',
#  'nasa/libSPRITE',
#  'nasa/channel-emulator',
#  'nasa/astrobee',
#  'nasa/astrobot',
#  'nasa/dictionaries',
#  'nasa/podaacpy',
#  'nasa/cumulus',
#  'nasa/mmt',
#  'nasa/digital-strategy',
#  'nasa/PrognosticsAlgorithmLibrary',
#  'nasa/CertWare',
#  'nasa/data.nasa.gov',
#  'nasa/code.nasa.gov_legacy',
#  'nasa/PyBlock',
#  'nasa/PrognosticsModelLibrary',
#  'nasa/SingleDop',
#  'nasa/mplStyle',
#  'nasa/DAVEtools',
#  'nasa/RtRetrievalFramework',
#  'nasa/GTM_DesignSim',
#  'nasa/DualPol',
#  'nasa/PolyCARP',
#  'nasa/CCDD',
#  'nasa/GFR',
#  'nasa/sitepod',
#  'nasa/multipath-tcp-tools',
#  'nasa/meshNetwork',
#  'nasa/common-mapping-client',
#  'nasa/gFTL',
#  'nasa/WinSURE',
#  'nasa/MISR-Toolkit',
#  'nasa/CompDam_DGD',
#  'nasa/edsc-timeline',
#  'nasa/PRECiSA',
#  'nasa/WinASSIST',
#  'nasa/abaverify',
#  'nasa/OpenVSP3Plugin',
#  'nasa/kepler-robovetter',
#  'nasa/edsc-echoforms',
#  'nasa/Open-Gov-Plan-v4',
#  'nasa/cmr-metadata-review',
#  'nasa/VirtualADAPT',
#  'nasa/TrickFMI',
#  'ReFRACtor/framework',
#  'nasa/astrobee_android',
#  'nasa/data-science-day',
#  'nasa/LH2Sim',
#  'nasa/MM',
#  'nasa/refine',
#  'nasa/SCH',
#  'nasa/nasapress',
#  'nasa/cfs_lib',
#  'nasa/aggregate-dictionary',
#  'nasa/MINX',
#  'nasa/RVLib',
#  'nasa/knife',
#  'nasa/MLMCPy',
#  'nasa/HK',
#  'nasa/RtRetrievalFrameworkDoc',
#  'nasa/HS',
#  'nasa/DS',
#  'nasa/SC',
#  'nasa/SBN',
#  'nasa/cFS',
#  'nasa/SAFE-DART',
#  'nasa/cumulus-message-adapter',
#  'nasa/SROMPy',
#  'nasa/MAV',
#  'nasa/KeplerPORTs',
#  'nasa/georef',
#  'nasa/Kepler-FLTI',
#  'nasa/georef_imageregistration',
#  'nasa/MD',
#  'nasa/CFS_IO_LIB',
#  'nasa/CF',
#  'nasa/LC',
#  'nasa/landslide',
#  'nasa/nasapress-companion',
#  'nasa/AGTF30',
#  'nasa/CS',
#  'nasa/CFS_CI',
#  'nasa/FM',
#  'nasa/CCSDS-MAL-API',
#  'nasa/cumulus-message-adapter-js',
#  'nasa/cumulus-message-adapter-python',
#  'ReFRACtor/documentation',
#  'nasa/georef_geocamtiepoint',
#  'nasa/georef_deploy',
#  'nasa/cmr-csw',
#  'nasa/DON-Federate-HLA2MPC',
#  'nasa/cmr-opensearch',
#  'nasa/centerops.jsc.nasa.gov',
#  'nasa/edsc-geo',
#  'nasa/Computational-Materials-Miniapp1',
#  'nasa/ominas',
#  'nasa/earthdata-search-test-config',
#  'nasa/CFS-101',
#  'nasa/CFS_TO',
#  'nasa/PrognosticsMetricsLibrary',
#  'nasa/georef_geocamutilweb',
#  'nasa/edsc-search-test-config-3',
#  'nasa/edsc-search-test-config-2',
#  'nasa/ESPRESSO',
#  'nasa/FEI',
#  'nasa/edsc-widgets']

# %%
query4 = """
SELECT *
 
 FROM 
  `bigquery-public-data.libraries_io.repository_dependencies` 
 
 WHERE 
 repository_name_with_owner IN ({names})
 
 LIMIT 
  1000
        """.format(names=', '.join('"' + name + '"' for name in names))
dependecies2 = library.query_to_pandas_safe(query4, max_gb_scanned=30)
dependecies2
# Out:
#             id host_type repository_name_with_owner  repository_id  \
# 0     22809949    GitHub      nasa/earthdata-search        2947341
# 1    169210215    GitHub        nasa/cmr-opensearch       26842375
# 2     29485665    GitHub        nasa/edsc-echoforms        6109462
# 3     22809670    GitHub      nasa/earthdata-search        2947341
# 4     29485653    GitHub        nasa/edsc-echoforms        6109462
# 5     22809719    GitHub      nasa/earthdata-search        2947341
# 6    193019369    GitHub              nasa/api-docs         850943
# 7     76320911    GitHub               nasa/openmct         850977
# 8    146009613    GitHub                   nasa/mct         844840
# 9    207164465    GitHub  nasa/georef_geocamutilweb       29480027
# 10   169211995    GitHub        nasa/cmr-opensearch       26842375
# 11   166749914    GitHub               nasa/cmr-csw       26666352
# 12   146010707    GitHub                   nasa/mct         844840
# 13   166750098    GitHub               nasa/cmr-csw       26666352
# 14   169212821    GitHub        nasa/cmr-opensearch       26842375
# 15   169212958    GitHub        nasa/cmr-opensearch       26842375
# 16   193020261    GitHub              nasa/api-docs         850943
# 17   193018401    GitHub              nasa/api-docs         850943
# 18   169211213    GitHub        nasa/cmr-opensearch       26842375
# 19   169215240    GitHub        nasa/cmr-opensearch       26842375
# 20   169213302    GitHub        nasa/cmr-opensearch       26842375
# 21   169213109    GitHub        nasa/cmr-opensearch       26842375
# 22    22809927    GitHub      nasa/earthdata-search        2947341
# 23   220896532    GitHub  nasa/RtRetrievalFramework        3878366
# 24   166749848    GitHub               nasa/cmr-csw       26666352
# 25   166749868    GitHub               nasa/cmr-csw       26666352
# 26    86371636    GitHub         nasa/code-nasa-gov       13133815
# 27   169211375    GitHub        nasa/cmr-opensearch       26842375
# 28    29485682    GitHub         nasa/edsc-timeline        6109463
# 29   220896234    GitHub  nasa/RtRetrievalFramework        3878366
# ..         ...       ...                        ...            ...
# 690   76321651    GitHub               nasa/openmct         850977
# 691  166749997    GitHub               nasa/cmr-csw       26666352
# 692   76320817    GitHub               nasa/openmct         850977
# 693  146009729    GitHub                   nasa/mct         844840
# 694   22809789    GitHub      nasa/earthdata-search        2947341
# 695  169214766    GitHub        nasa/cmr-opensearch       26842375
# 696   29485660    GitHub        nasa/edsc-echoforms        6109462
# 697   22809808    GitHub      nasa/earthdata-search        2947341
# 698  193020066    GitHub              nasa/api-docs         850943
# 699  146010830    GitHub                   nasa/mct         844840
# 700  169215475    GitHub        nasa/cmr-opensearch       26842375
# 701   29485676    GitHub        nasa/edsc-echoforms        6109462
# 702   29485687    GitHub         nasa/edsc-timeline        6109463
# 703   22810038    GitHub      nasa/earthdata-search        2947341
# 704   22810157    GitHub      nasa/earthdata-search        2947341
# 705  193020288    GitHub              nasa/api-docs         850943
# 706  162298470    GitHub              nasa/apod-api       26378983
# 707   86371567    GitHub         nasa/code-nasa-gov       13133815
# 708  166749912    GitHub               nasa/cmr-csw       26666352
# 709   76321115    GitHub               nasa/openmct         850977
# 710   22810013    GitHub      nasa/earthdata-search        2947341
# 711   22809865    GitHub      nasa/earthdata-search        2947341
# 712  169213496    GitHub        nasa/cmr-opensearch       26842375
# 713  169215395    GitHub        nasa/cmr-opensearch       26842375
# 714  169210313    GitHub        nasa/cmr-opensearch       26842375
# 715   22810055    GitHub      nasa/earthdata-search        2947341
# 716  207164226    GitHub  nasa/georef_geocamutilweb       29480027
# 717   22809963    GitHub      nasa/earthdata-search        2947341
# 718  169213216    GitHub        nasa/cmr-opensearch       26842375
# 719   22810154    GitHub      nasa/earthdata-search        2947341
#
#     manifest_platform                                  manifest_filepath  \
# 0            Rubygems                                       Gemfile.lock
# 1            rubygems                                            Gemfile
# 2                 NPM                                       package.json
# 3            Rubygems                                            Gemfile
# 4                 NPM                                       package.json
# 5            Rubygems                                            Gemfile
# 6            rubygems                                       Gemfile.lock
# 7               Bower                                         bower.json
# 8               maven                                      batik/pom.xml
# 9                pypi  geocamUtil/example/submodules/app2/requirement...
# 10           rubygems                                       Gemfile.lock
# 11           rubygems                                       Gemfile.lock
# 12              maven                                 tableViews/pom.xml
# 13           rubygems                                       Gemfile.lock
# 14           rubygems                                       Gemfile.lock
# 15           rubygems                                       Gemfile.lock
# 16           rubygems                                       Gemfile.lock
# 17           rubygems                                            Gemfile
# 18           rubygems                                       Gemfile.lock
# 19           rubygems                                       Gemfile.lock
# 20           rubygems                                       Gemfile.lock
# 21           rubygems                                       Gemfile.lock
# 22           Rubygems                                       Gemfile.lock
# 23               pypi                                   requirements.txt
# 24           rubygems                                            Gemfile
# 25           rubygems                                       Gemfile.lock
# 26              Bower                                         bower.json
# 27           rubygems                                       Gemfile.lock
# 28                NPM                                       package.json
# 29               pypi                                   requirements.txt
# ..                ...                                                ...
# 690               NPM                                       package.json
# 691          rubygems                                       Gemfile.lock
# 692             Bower                                         bower.json
# 693             maven                                      batik/pom.xml
# 694          Rubygems                                       Gemfile.lock
# 695          rubygems                                       Gemfile.lock
# 696               NPM                                       package.json
# 697          Rubygems                                       Gemfile.lock
# 698          rubygems                                       Gemfile.lock
# 699             maven                 timeSequenceFeedAggregator/pom.xml
# 700          rubygems                                       Gemfile.lock
# 701               NPM                                       package.json
# 702               NPM                                       package.json
# 703          Rubygems                                       Gemfile.lock
# 704               NPM                                       package.json
# 705          rubygems                                       Gemfile.lock
# 706              pypi                                   requirements.txt
# 707             Bower                                         bower.json
# 708          rubygems                                       Gemfile.lock
# 709               NPM                                       package.json
# 710          Rubygems                                       Gemfile.lock
# 711          Rubygems                                       Gemfile.lock
# 712          rubygems                                       Gemfile.lock
# 713          rubygems                                       Gemfile.lock
# 714          rubygems                                            Gemfile
# 715          Rubygems                                       Gemfile.lock
# 716              pypi  geocamUtil/example/submodules/app1/requirement...
# 717          Rubygems                                       Gemfile.lock
# 718          rubygems                                       Gemfile.lock
# 719               NPM                                       package.json
#
#     git_branch manifest_kind optional   dependency_project_name  \
# 0                   lockfile                     multipart-post
# 1                   manifest                       therubyracer
# 2                   manifest                      karma-webpack
# 3                   manifest                        rspec-rails
# 4                   manifest                       jasmine-core
# 5                   manifest                           uglifier
# 6                   lockfile               middleman-livereload
# 7                   manifest                      eventemitter3
# 8                   manifest                  batik:batik-swing
# 9                   manifest                             dutest
# 10                  lockfile                      coffee-script
# 11                  lockfile                              netrc
# 12                  manifest           gov.nasa.arc.mct:mctcore
# 13                  lockfile                        thread_safe
# 14                  lockfile                               hike
# 15                  lockfile                       jquery-rails
# 16                  lockfile                               uber
# 17                  manifest                   middleman-syntax
# 18                  lockfile                       actionmailer
# 19                  lockfile                          sprockets
# 20                  lockfile                         mime-types
# 21                  lockfile                               kgio
# 22                  lockfile                              libv8
# 23                  manifest                             pyproj
# 24                  manifest                            webmock
# 25                  lockfile                      coffee-script
# 26                  manifest               web-component-tester
# 27                  lockfile                        activemodel
# 28                  manifest                     jasmine-jquery
# 29                  manifest                               h5py
# ..         ...           ...      ...                       ...
# 690                 manifest                  gulp-replace-task
# 691                 lockfile               rails-html-sanitizer
# 692                 manifest             moment-duration-format
# 693                 manifest                    batik:batik-ext
# 694                 lockfile                            bourbon
# 695                 lockfile                        rspec-mocks
# 696                 manifest                          karma-cli
# 697                 lockfile                       coffee-rails
# 698                 lockfile                       therubyracer
# 699                 manifest              gov.nasa.arc.mct:util
# 700                 lockfile                             tzinfo
# 701                 manifest                            webpack
# 702                 manifest                          karma-cli
# 703                 lockfile                       therubyracer
# 704                 manifest           karma-phantomjs-launcher
# 705                 lockfile                           uglifier
# 706                 manifest                           Werkzeug
# 707                 manifest                          iron-list
# 708                 lockfile                           minitest
# 709                 manifest                               gulp
# 710                 lockfile                   ruby-progressbar
# 711                 lockfile                       factory_girl
# 712                 lockfile                              netrc
# 713                 lockfile                               tilt
# 714                 manifest                       jquery-rails
# 715                 lockfile                             tzinfo
# 716                 manifest                             dutest
# 717                 lockfile                       quiet_assets
# 718                 lockfile                               mail
# 719                 manifest                      karma-jasmine
#
#                dependency_requirements dependency_kind  dependency_project_id
# 0                                1.2.0         runtime               226680.0
# 1                                 >= 0     development               259307.0
# 2                               ^1.7.0     development               292395.0
# 3                                 >= 0     development               245284.0
# 4                               ^2.3.4     development               161117.0
# 5                             >= 1.3.0     development               263406.0
# 6                                3.3.4         runtime               223617.0
# 7                               ^1.2.0         runtime               768109.0
# 8                                  1.6         runtime               351630.0
# 9                                ==0.1         runtime                44251.0
# 10                               2.2.0         runtime               189640.0
# 11                              0.11.0         runtime               228330.0
# 12             ${mct.platform.version}        provided                    NaN
# 13                               0.3.5         runtime               259551.0
# 14                               1.2.3         runtime               209906.0
# 15                               3.0.4         runtime               215410.0
# 16                              0.0.13         runtime               263304.0
# 17                                >= 0         runtime               223666.0
# 18                            3.2.22.4         runtime                42897.0
# 19                               2.2.3         runtime               254753.0
# 20                              1.25.1         runtime               223861.0
# 21                              2.10.0         runtime               216874.0
# 22                           3.11.8.17         runtime               218875.0
# 23                                   *         runtime                71534.0
# 24                                >= 0     development               267353.0
# 25                               2.4.1         runtime               189640.0
# 26                              ^4.0.0     development                26046.0
# 27                            3.2.22.4         runtime                44770.0
# 28                              ^2.1.0     development               161127.0
# 29                                   *         runtime                50310.0
# ..                                 ...             ...                    ...
# 690                            ^0.11.0     development               288244.0
# 691                              1.0.3         runtime               239470.0
# 692                             ^1.3.0         runtime                17696.0
# 693                                1.6         runtime               639286.0
# 694                              3.2.1         runtime               184278.0
# 695                             2.14.4         runtime               245231.0
# 696                             ^0.1.0     development               292361.0
# 697                              4.0.1         runtime               189636.0
# 698                             0.12.1         runtime               259307.0
# 699            ${mct.platform.version}        provided                    NaN
# 700                             0.3.51         runtime               263275.0
# 701                            ^1.12.1     development               330445.0
# 702                             ^0.1.0     development               292361.0
# 703                             0.11.4         runtime               259307.0
# 704                             ^0.2.1     development               163588.0
# 705                              2.7.0         runtime               263406.0
# 706                           ==0.10.4         runtime                87626.0
# 707  PolymerElements/iron-list#^1.3.11         runtime              1261178.0
# 708                              5.9.0         runtime               224097.0
# 709                             ^3.9.0     development               287937.0
# 710                              1.5.0         runtime               246640.0
# 711                              4.4.0         runtime               200105.0
# 712                             0.10.3         runtime               228330.0
# 713                              1.4.1         runtime               259818.0
# 714                               >= 0         runtime               215410.0
# 715                              1.2.2         runtime               263275.0
# 716                            ==0.2.3         runtime                44251.0
# 717                              1.0.2         runtime               237652.0
# 718                              2.5.4         runtime               221129.0
# 719                             ^0.3.6     development               163505.0
#
# [720 rows x 13 columns]
