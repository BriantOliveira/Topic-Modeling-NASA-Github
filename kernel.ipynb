# %%
import bq_helper
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from bq_helper import BigQueryHelper
library = bq_helper.BigQueryHelper(active_project="bigquery-public-data",
                                   dataset_name="libraries_io")

# %%
bq_assistant = BigQueryHelper("bigquery-public-data", "libraries_io")
bq_assistant.list_tables()
# Out:
# ['dependencies',
#  'projects',
#  'projects_with_repository_fields',
#  'repositories',
#  'repository_dependencies',
#  'tags',
#  'versions']

# %%
bq_assistant.head("repositories", num_rows=20)
# Out:
#           id  host_type                                    name_with_owner  \
# 0    6398626     GitHub                        iVision360/DeepLearnToolbox
# 1   26733060     GitHub                    jjn1056/App--local--lib--helper
# 2    6322348     GitHub                                       zennoc/puppi
# 3   23831459     GitHub                         rytkmt/rytkmt_vim_settings
# 4    5894058     GitHub                                  Rhaptos/cnxmobile
# 5    6137936     GitHub                  saltstack-formulas/rsyncd-formula
# 6   12830415     GitHub       IntershopCommunicationsAG/test-gradle-plugin
# 7    3016663     GitHub                                  madokama/org-mode
# 8   31848396     GitHub  codecentral-examples/how-to-detect-state-of-a-...
# 9   29632022     GitHub                        Catherinezou/lowpass_filter
# 10   6028785     GitHub                    packetloop/vmware-tools-formula
# 11  25159082     GitHub  codecentral-examples/E1156-How-to-copy-a-chart...
# 12   6305664     GitHub                  bsmr-emacs/emagicians-starter-kit
# 13  25609784     GitHub                              vances42/lock-manager
# 14  23463599     GitHub                      codeThatThinks/Quadcopter-PDB
# 15   9431012     GitHub                            briandfoy/psychic-ninja
# 16  22641272     GitHub                                hoxo-m/hoxomodeling
# 17   5729392     GitHub                                   jhekasoft/lifter
# 18  29517400     GitHub                                 ColinFay/tweetthat
# 19  23514527  Bitbucket                                 clojuresque/extras
#
#                                           description   fork  \
# 0   Matlab/Octave toolbox for deep learning. Inclu...   True
# 1                    Make it easier to use local::lib  False
# 2   Puppet module to manage applications deploymen...   True
# 3                                                      False
# 4        Mobile site for Connexions using Deliverance  False
# 5                                 Salt rsyncd formula   True
# 6   Gradle test plugin - test extension for Gradle...  False
# 7                                                      False
# 8               .NET, ASP.NET Web Forms, ASPxGridView  False
# 9                                                      False
# 10                                                      True
# 11                                                     False
# 12  My own take on the Emacs Starter Kit, with Sec...   True
# 13                                                     False
# 14  Quadcopter power distribution board rated for ...  False
# 15                                                     False
# 16                                                     False
# 17                           Игра «Лифтёр» на INSTEAD  False
# 18  A simple wrapper to tweet straight from your R...  False
# 19      Extra tasks for the clojuresque gradle plugin  False
#
#            created_timestamp         updated_timestamp  \
# 0  2014-06-10 11:48:36+00:00 2017-04-07 22:06:49+00:00
# 1  2010-08-04 12:58:16+00:00 2017-07-30 15:36:31+00:00
# 2  2012-12-20 13:36:28+00:00 2017-04-06 20:01:21+00:00
# 3  2016-08-19 02:52:33+00:00 2017-05-04 11:05:03+00:00
# 4  2014-03-17 16:23:32+00:00 2014-03-26 19:46:29+00:00
# 5  2015-05-28 00:42:47+00:00 2017-03-31 18:53:00+00:00
# 6  2016-03-25 15:49:06+00:00 2017-08-04 20:01:47+00:00
# 7  2015-11-06 06:11:09+00:00 2018-01-30 23:05:04+00:00
# 8  2018-02-24 10:30:47+00:00 2018-02-24 10:30:54+00:00
# 9  2017-10-19 20:30:03+00:00 2017-10-19 23:17:15+00:00
# 10 2014-12-23 04:22:27+00:00 2017-03-21 13:40:54+00:00
# 11 2017-09-19 22:04:07+00:00 2017-09-19 22:07:20+00:00
# 12 2015-11-14 17:44:06+00:00 2015-11-14 17:44:08+00:00
# 13 2017-06-29 17:01:28+00:00 2017-06-29 17:04:30+00:00
# 14 2017-02-13 20:22:10+00:00 2017-07-18 16:24:12+00:00
# 15 2013-02-13 03:02:46+00:00 2017-09-22 22:36:53+00:00
# 16 2015-05-27 03:46:11+00:00 2018-01-16 15:58:20+00:00
# 17 2013-07-04 20:25:49+00:00 2017-01-25 15:07:39+00:00
# 18 2017-10-02 09:18:45+00:00 2018-01-16 16:57:23+00:00
# 19 2013-10-03 20:41:51+00:00 2015-10-22 05:56:12+00:00
#
#        last_pushed_timestamp  \
# 0  2014-05-11 12:46:19+00:00
# 1  2011-10-06 13:41:01+00:00
# 2  2014-08-04 09:29:08+00:00
# 3  2017-05-04 11:01:17+00:00
# 4  2014-03-26 19:46:31+00:00
# 5  2017-03-16 14:31:22+00:00
# 6  2017-08-09 09:27:53+00:00
# 7  2016-01-24 17:37:55+00:00
# 8  2018-02-24 10:30:54+00:00
# 9  2017-10-19 20:40:24+00:00
# 10 2015-01-21 03:03:29+00:00
# 11 2017-09-19 22:04:15+00:00
# 12 2015-07-16 16:35:42+00:00
# 13 2017-06-29 17:02:12+00:00
# 14 2017-02-13 20:41:12+00:00
# 15 2015-09-08 06:16:58+00:00
# 16 2015-05-27 09:18:41+00:00
# 17 2013-07-15 10:39:42+00:00
# 18 2017-12-27 12:30:25+00:00
# 19                       NaT
#
#                                          homepage_url   size  ...  \
# 0                                                      17393  ...
# 1   http://search.cpan.org/dist/App-local-lib-helper/    151  ...
# 2                            http://www.example42.com    628  ...
# 3                                                         64  ...
# 4                                                      13174  ...
# 5   http://docs.saltstack.com/en/latest/topics/dev...     16  ...
# 6                                                        158  ...
# 7                                                      70474  ...
# 8        https://codecentral.devexpress.com/undefined      0  ...
# 9                                                         46  ...
# 10  http://docs.saltstack.com/en/latest/topics/dev...     67  ...
# 11                                                         0  ...
# 12                                                     12264  ...
# 13                                                         0  ...
# 14                                                       100  ...
# 15                                                       288  ...
# 16                                                       312  ...
# 17                                                      6140  ...
# 18                                                     24614  ...
# 19                                                       465  ...
#
#     security_audit_filename status     last_synced_timestamp  sourcerank  \
# 0                                                        NaT           4
# 1                                  2017-07-30 15:36:30+00:00           4
# 2                                                        NaT           0
# 3                                  2017-05-04 11:05:01+00:00           3
# 4                                                        NaT           3
# 5                                                        NaT           0
# 6                                  2016-08-23 08:46:59+00:00           4
# 7                                                        NaT           4
# 8                                  2018-01-21 00:59:12+00:00           3
# 9                                  2017-10-19 23:17:14+00:00           3
# 10                                                       NaT           3
# 11                                 2017-09-19 22:07:20+00:00           3
# 12                                                       NaT           0
# 13                                 2017-06-29 17:04:30+00:00           3
# 14                                 2017-04-23 02:27:26+00:00           2
# 15                                 2017-09-22 22:36:53+00:00           3
# 16                                 2018-01-16 15:58:19+00:00           3
# 17                                                       NaT           2
# 18                                 2018-01-16 16:57:23+00:00           4
# 19                                 2017-04-25 03:53:17+00:00           1
#
#    display_name  scm_type pull_requests_enabled  logo_url keywords  \
# 0        GitHub
# 1        GitHub                             git
# 2        GitHub
# 3        GitHub
# 4        GitHub                             git
# 5        GitHub
# 6        GitHub                             git
# 7        GitHub
# 8        GitHub                             git
# 9        GitHub                             git
# 10       GitHub
# 11       GitHub                             git
# 12       GitHub
# 13       GitHub
# 14       GitHub
# 15       GitHub                             git
# 16       GitHub                             git
# 17       GitHub
# 18       GitHub                             git
# 19    Bitbucket                              hg
#
#                                         an
# 0
# 1
# 2
# 3
# 4
# 5
# 6   development-tools,gradle,testing-tools
# 7
# 8
# 9
# 10
# 11
# 12
# 13
# 14
# 15                                    perl
# 16
# 17
# 18
# 19
#
# [20 rows x 40 columns]

# %%
bq_assistant.table_schema("repositories")
# Out:
#                                 name       type      mode  \
# 0                                 id    INTEGER  NULLABLE
# 1                          host_type     STRING  NULLABLE
# 2                    name_with_owner     STRING  NULLABLE
# 3                        description     STRING  NULLABLE
# 4                               fork    BOOLEAN  NULLABLE
# 5                  created_timestamp  TIMESTAMP  NULLABLE
# 6                  updated_timestamp  TIMESTAMP  NULLABLE
# 7              last_pushed_timestamp  TIMESTAMP  NULLABLE
# 8                       homepage_url     STRING  NULLABLE
# 9                               size    INTEGER  NULLABLE
# 10                       stars_count    INTEGER  NULLABLE
# 11                          language     STRING  NULLABLE
# 12                    issues_enabled    BOOLEAN  NULLABLE
# 13                      wiki_enabled    BOOLEAN  NULLABLE
# 14                     pages_enabled    BOOLEAN  NULLABLE
# 15                       forks_count    INTEGER  NULLABLE
# 16                        mirror_url     STRING  NULLABLE
# 17                 open_issues_count    INTEGER  NULLABLE
# 18                    default_branch     STRING  NULLABLE
# 19                    watchers_count    INTEGER  NULLABLE
# 20                              uuid     STRING  NULLABLE
# 21       fork_source_name_with_owner     STRING  NULLABLE
# 22                           license     STRING  NULLABLE
# 23                contributors_count    INTEGER  NULLABLE
# 24                   readme_filename     STRING  NULLABLE
# 25                changelog_filename     STRING  NULLABLE
# 26  contributing_guidelines_filename     STRING  NULLABLE
# 27                  license_filename     STRING  NULLABLE
# 28          code_of_conduct_filename     STRING  NULLABLE
# 29    security_threat_model_filename     STRING  NULLABLE
# 30           security_audit_filename     STRING  NULLABLE
# 31                            status     STRING  NULLABLE
# 32             last_synced_timestamp  TIMESTAMP  NULLABLE
# 33                        sourcerank    INTEGER  NULLABLE
# 34                      display_name     STRING  NULLABLE
# 35                          scm_type     STRING  NULLABLE
# 36             pull_requests_enabled     STRING  NULLABLE
# 37                          logo_url     STRING  NULLABLE
# 38                          keywords     STRING  NULLABLE
# 39                                an     STRING  NULLABLE
#
#                                           description
# 0   he unique primary key of the repository in the...
# 1   Which website the repository is hosted on, eit...
# 2   The repository name and owner seperated by a s...
# 3                          Description of repository.
# 4                Is the repository a fork of another.
# 5   Timestamp of when the repository was created o...
# 6   Timestamp of when the repository was last save...
# 7   Timestamp of when the repository was last push...
# 8   URL of a declared homepage or other website fo...
# 9   Size of the repository in kilobytes, only avai...
# 10  Number of stars on the repository, only availa...
# 11  Primary programming language the project is wr...
# 12   Is the bug tracker enabled for this repository?.
# 13          Is the wiki enabled for this repository?.
# 14  Is GitHub pages enabled for this repository? o...
# 15                Number of forks of this repository.
# 16  URL of the repositroy of which this is a mirro...
# 17  Number of open issues on the repository bug tr...
# 18                  Primary branch of the repository.
# 19  Number of subscribers to all notifications for...
# 20  ID of the repository on the remote host, not u...
# 21  If the repository is a fork, the repository na...
# 22  SPDX identifier of the license of the reposito...
# 23  Number of unique contributors that have commit...
# 24  If a readme file has been detected, the full n...
# 25  If a changelog file has been detected, the ful...
# 26  If a contributing guidelines file has been det...
# 27  If a license file has been detected, the full ...
# 28  If a code of conduct file has been detected, t...
# 29  If a Security Threat Model file has been detec...
# 30  If a Security Audit file has been detected, th...
# 31  Either Active, Deprecated, Unmaintained, Help ...
# 32  Timestamp of when Libraries.io last synced the...
# 33  Libraries.io defined score based on quality, p...
# 34  Display name for the repository, only availabl...
# 35  Type of source control repository uses, always...
# 36  Are pull requests enabled for this repository?...
# 37  Custom logo url for repository, only available...
# 38  Comma separated array of keywords, called "top...
# 39

# %% [markdown]
# What are the repositories, avg project size, and avg # of stars?

# %%
query1 = """
SELECT
  host_type,
  COUNT(*) repositories,
  ROUND(AVG(size),2) avg_size,
  ROUND(AVG(stars_count),2) avg_stars
FROM
  `bigquery-public-data.libraries_io.repositories`
GROUP BY
  host_type
ORDER BY
  repositories DESC
LIMIT
  1000;
        """
response1 = library.query_to_pandas_safe(query1)
response1.head(10)
# Out:
#    host_type  repositories  avg_size  avg_stars
# 0     GitHub      30238391   6165.09       3.18
# 1  Bitbucket        252305  16029.57       0.00
# 2     GitLab        214938   5367.22       0.05

# %% [markdown]
# What are the top dependencies per platform?

# %%
query2 = """
SELECT
  dependency_platform,
  COUNT(*) dependencies,
  APPROX_TOP_COUNT(dependency_name, 3) top_dependencies
FROM
  `bigquery-public-data.libraries_io.dependencies`
GROUP BY
  dependency_platform
ORDER BY
  dependencies DESC;
        """
response2 = library.query_to_pandas_safe(query2, max_gb_scanned=10)
response2.head(20)
# Out:
#    dependency_platform  dependencies  \
# 0                  NPM      52886648
# 1             Rubygems       4487068
# 2            Packagist       4178018
# 3                Maven       3592035
# 4                NuGet       3097656
# 5                 CPAN       2406593
# 6                Cargo        350862
# 7                 CRAN        277856
# 8                  Npm        215433
# 9                 Pypi        126535
# 10                 Pub        119810
# 11              Puppet         57292
# 12                 Hex         50227
# 13                 Elm         16450
# 14                 Dub         11410
# 15             Haxelib          5776
# 16            Homebrew          4886
#
#                                      top_dependencies
# 0   [{'value': 'mocha', 'count': 1129627}, {'value...
# 1   [{'value': 'rake', 'count': 366136}, {'value':...
# 2   [{'value': 'phpunit/phpunit', 'count': 332742}...
# 3   [{'value': 'junit:junit', 'count': 156591}, {'...
# 4   [{'value': 'Newtonsoft.Json', 'count': 165805}...
# 5   [{'value': 'Test-More', 'count': 139176}, {'va...
# 6   [{'value': 'serde', 'count': 13800}, {'value':...
# 7   [{'value': 'R', 'count': 43374}, {'value': 'st...
# 8   [{'value': 'atom-space-pen-views', 'count': 12...
# 9   [{'value': 'requests', 'count': 7999}, {'value...
# 10  [{'value': 'unittest', 'count': 9677}, {'value...
# 11  [{'value': 'puppetlabs-stdlib', 'count': 16516...
# 12  [{'value': 'poison', 'count': 6552}, {'value':...
# 13  [{'value': 'elm-lang/core', 'count': 5634}, {'...
# 14  [{'value': 'vibe-d', 'count': 606}, {'value': ...
# 15  [{'value': 'openfl', 'count': 442}, {'value': ...
# 16  [{'value': 'Pkg-config', 'count': 454}, {'valu...

# %% [markdown]
# What are the top unmaintained or deprecated projects?

# %%
query3 = """
SELECT
  name,
  repository_sourcerank,
  LANGUAGE,
  status
FROM
  `bigquery-public-data.libraries_io.projects_with_repository_fields`
WHERE
  status IN ('Deprecated',
    'Unmaintained')
ORDER BY
  repository_sourcerank DESC
LIMIT
  20;
        """
response3 = library.query_to_pandas_safe(query3, max_gb_scanned=10)
response3.head(20)
# Out:
#                                          name  repository_sourcerank  \
# 0                          react-linked-input                     27
# 1                   external-react-hot-loader                     22
# 2       org.eclipse.jetty:jetty-documentation                     22
# 3                                       spree                     20
# 4                  pouchdb-abstract-mapreduce                     19
# 5                           pouchdb-mapreduce                     19
# 6                                    unittest                     18
# 7                                        jade                     18
# 8                                        jscs                     16
# 9                                    edp-jscs                     16
# 10                           facebook/php-sdk                     16
# 11                                    wiredep                     16
# 12                                      jscs2                     16
# 13                        akavache.deprecated                     16
# 14                                  scss-lint                     16
# 15      org.igniterealtime.smack:smack-jingle                     15
# 16                                   html5lib                     15
# 17                        tidepool-data-model                     15
# 18  org.igniterealtime.smack:smack-jingle-old                     15
# 19                                      Shave                     15
#
#       LANGUAGE        status
# 0   JavaScript  Unmaintained
# 1   JavaScript    Deprecated
# 2         Java    Deprecated
# 3         Ruby    Deprecated
# 4   JavaScript    Deprecated
# 5   JavaScript    Deprecated
# 6         Dart    Deprecated
# 7   JavaScript    Deprecated
# 8   JavaScript    Deprecated
# 9   JavaScript    Deprecated
# 10         PHP    Deprecated
# 11  JavaScript  Unmaintained
# 12  JavaScript    Deprecated
# 13          C#    Deprecated
# 14        Ruby    Deprecated
# 15        Java  Unmaintained
# 16        Dart    Deprecated
# 17                Deprecated
# 18        Java  Unmaintained
# 19                Deprecated

# %% [markdown]
# Credit: Many functions are adapted from https://console.cloud.google.com/marketplace/details/libraries-io/librariesio

# %%
import requests 

r = requests.get('https://libraries.io/api/github/nasa/repositories?api_key=91f3f771438b366da564093e002a2c61&per_page=200')
project_names = r.json()
names = list(map(lambda x: x['full_name'], project_names))
names
# Out:
# ['nasa/openmct',
#  'nasa/NASA-3D-Resources',
#  'nasa/mct',
#  'nasa/earthdata-search',
#  'nasa/trick',
#  'nasa/isle',
#  'nasa/api-docs',
#  'nasa/VICAR',
#  'nasa/code-nasa-gov',
#  'nasa/XPlaneConnect',
#  'nasa/apod-api',
#  'nasa/Open-Source-Catalog',
#  'nasa/osal',
#  'nasa/nasa-latex-docs',
#  'nasa/CrisisMappingToolkit',
#  'nasa/NASTRAN-95',
#  'nasa/QuIP',
#  'nasa/T-MATS',
#  'nasa/DERT',
#  'nasa/autodoc',
#  'nasa/pvslib',
#  'nasa/CFL3D',
#  'nasa/Common-Metadata-Repository',
#  'nasa/Kodiak',
#  'nasa/OpenSPIFe',
#  'nasa/kepler-pipeline',
#  'nasa/cumulus',
#  'nasa/icarous',
#  'nasa/RHEAS',
#  'nasa/IDF',
#  'nasa/fprime',
#  'nasa/PyTDA',
#  'nasa/ipv6_python',
#  'nasa/libSPRITE',
#  'nasa/channel-emulator',
#  'nasa/astrobee',
#  'nasa/astrobot',
#  'nasa/dictionaries',
#  'nasa/podaacpy',
#  'nasa/mmt',
#  'nasa/digital-strategy',
#  'nasa/PrognosticsAlgorithmLibrary',
#  'nasa/CertWare',
#  'nasa/data.nasa.gov',
#  'nasa/code.nasa.gov_legacy',
#  'nasa/PyBlock',
#  'nasa/PrognosticsModelLibrary',
#  'nasa/SingleDop',
#  'nasa/mplStyle',
#  'nasa/DAVEtools',
#  'nasa/RtRetrievalFramework',
#  'nasa/GTM_DesignSim',
#  'nasa/DualPol',
#  'nasa/PolyCARP',
#  'nasa/CCDD',
#  'nasa/GFR',
#  'nasa/sitepod',
#  'nasa/multipath-tcp-tools',
#  'nasa/common-mapping-client',
#  'nasa/meshNetwork',
#  'nasa/WinSURE',
#  'nasa/gFTL',
#  'nasa/MISR-Toolkit',
#  'nasa/CompDam_DGD',
#  'nasa/edsc-timeline',
#  'nasa/PRECiSA',
#  'nasa/WinASSIST',
#  'nasa/abaverify',
#  'nasa/OpenVSP3Plugin',
#  'nasa/kepler-robovetter',
#  'nasa/edsc-echoforms',
#  'nasa/Open-Gov-Plan-v4',
#  'nasa/cmr-metadata-review',
#  'nasa/VirtualADAPT',
#  'nasa/TrickFMI',
#  'ReFRACtor/framework',
#  'nasa/astrobee_android',
#  'nasa/data-science-day',
#  'nasa/LH2Sim',
#  'nasa/cfs_lib',
#  'nasa/refine',
#  'nasa/SCH',
#  'nasa/MM',
#  'nasa/nasapress',
#  'nasa/aggregate-dictionary',
#  'nasa/knife',
#  'nasa/MLMCPy',
#  'nasa/MINX',
#  'nasa/RVLib',
#  'nasa/DS',
#  'nasa/SBN',
#  'nasa/SAFE-DART',
#  'nasa/SC',
#  'nasa/cFS',
#  'nasa/HS',
#  'nasa/HK',
#  'nasa/RtRetrievalFrameworkDoc',
#  'nasa/cumulus-message-adapter',
#  'nasa/SROMPy',
#  'nasa/georef',
#  'nasa/KeplerPORTs',
#  'nasa/MAV',
#  'nasa/georef_imageregistration',
#  'nasa/Kepler-FLTI',
#  'nasa/FM',
#  'nasa/AGTF30',
#  'nasa/MD',
#  'nasa/CFS_IO_LIB',
#  'nasa/CF',
#  'nasa/CCSDS-MAL-API',
#  'nasa/CFS_CI',
#  'nasa/landslide',
#  'nasa/nasapress-companion',
#  'nasa/CS',
#  'nasa/LC',
#  'nasa/cumulus-message-adapter-js',
#  'nasa/cumulus-message-adapter-python',
#  'ReFRACtor/documentation',
#  'nasa/DON-Federate-HLA2MPC',
#  'nasa/cmr-csw',
#  'nasa/georef_deploy',
#  'nasa/georef_geocamtiepoint',
#  'nasa/cmr-opensearch',
#  'nasa/PrognosticsMetricsLibrary',
#  'nasa/edsc-search-test-config-3',
#  'nasa/centerops.jsc.nasa.gov',
#  'nasa/edsc-search-test-config-2',
#  'nasa/georef_geocamutilweb',
#  'nasa/ESPRESSO',
#  'nasa/ominas',
#  'nasa/CFS-101',
#  'nasa/earthdata-search-test-config',
#  'nasa/CFS_TO',
#  'nasa/Computational-Materials-Miniapp1',
#  'nasa/edsc-geo',
#  'nasa/FEI',
#  'nasa/edsc-widgets']

# %%
query4 = """
SELECT *
 
 FROM 
  `bigquery-public-data.libraries_io.repository_dependencies` 
 
 WHERE 
 repository_name_with_owner IN ({names})
 
 LIMIT 
  1000
        """.format(names=', '.join('"' + name + '"' for name in names))
dependecies2 = library.query_to_pandas_safe(query4, max_gb_scanned=30)
all_dependencies = pd.DataFrame(dependecies2)
all_dependencies
# Out:
#             id host_type repository_name_with_owner  repository_id  \
# 0    169212682    GitHub        nasa/cmr-opensearch       26842375
# 1     22810161    GitHub      nasa/earthdata-search        2947341
# 2     22810081    GitHub      nasa/earthdata-search        2947341
# 3    146010707    GitHub                   nasa/mct         844840
# 4    166750083    GitHub               nasa/cmr-csw       26666352
# 5    193018582    GitHub              nasa/api-docs         850943
# 6    203041740    GitHub             nasa/nasapress       29299676
# 7    146010372    GitHub                   nasa/mct         844840
# 8    146009506    GitHub                   nasa/mct         844840
# 9     29485669    GitHub        nasa/edsc-echoforms        6109462
# 10   169213929    GitHub        nasa/cmr-opensearch       26842375
# 11   203041783    GitHub             nasa/nasapress       29299676
# 12    29485646    GitHub        nasa/edsc-echoforms        6109462
# 13   203041763    GitHub             nasa/nasapress       29299676
# 14   166749852    GitHub               nasa/cmr-csw       26666352
# 15    22809731    GitHub      nasa/earthdata-search        2947341
# 16    29485647    GitHub        nasa/edsc-echoforms        6109462
# 17    22810173    GitHub      nasa/earthdata-search        2947341
# 18   169213109    GitHub        nasa/cmr-opensearch       26842375
# 19   193018619    GitHub              nasa/api-docs         850943
# 20   166749848    GitHub               nasa/cmr-csw       26666352
# 21   169210487    GitHub        nasa/cmr-opensearch       26842375
# 22    76321034    GitHub               nasa/openmct         850977
# 23   146009962    GitHub                   nasa/mct         844840
# 24   166749858    GitHub               nasa/cmr-csw       26666352
# 25   193019369    GitHub              nasa/api-docs         850943
# 26   193019033    GitHub              nasa/api-docs         850943
# 27    22809896    GitHub      nasa/earthdata-search        2947341
# 28    29485670    GitHub        nasa/edsc-echoforms        6109462
# 29    76320911    GitHub               nasa/openmct         850977
# ..         ...       ...                        ...            ...
# 690  169210619    GitHub        nasa/cmr-opensearch       26842375
# 691  193019953    GitHub              nasa/api-docs         850943
# 692   29485697    GitHub         nasa/edsc-timeline        6109463
# 693  169211675    GitHub        nasa/cmr-opensearch       26842375
# 694   22809695    GitHub      nasa/earthdata-search        2947341
# 695  169212265    GitHub        nasa/cmr-opensearch       26842375
# 696  166749866    GitHub               nasa/cmr-csw       26666352
# 697  146009848    GitHub                   nasa/mct         844840
# 698  169213750    GitHub        nasa/cmr-opensearch       26842375
# 699  166749868    GitHub               nasa/cmr-csw       26666352
# 700  166749897    GitHub               nasa/cmr-csw       26666352
# 701   22810171    GitHub      nasa/earthdata-search        2947341
# 702   22810070    GitHub      nasa/earthdata-search        2947341
# 703  166749859    GitHub               nasa/cmr-csw       26666352
# 704  169214507    GitHub        nasa/cmr-opensearch       26842375
# 705   22809805    GitHub      nasa/earthdata-search        2947341
# 706  146009444    GitHub                   nasa/mct         844840
# 707   29485658    GitHub         nasa/edsc-timeline        6109463
# 708  166749882    GitHub               nasa/cmr-csw       26666352
# 709  166749869    GitHub               nasa/cmr-csw       26666352
# 710  166749921    GitHub               nasa/cmr-csw       26666352
# 711   22809978    GitHub      nasa/earthdata-search        2947341
# 712   22810006    GitHub      nasa/earthdata-search        2947341
# 713  193018985    GitHub              nasa/api-docs         850943
# 714   29485672    GitHub        nasa/edsc-echoforms        6109462
# 715  193020102    GitHub              nasa/api-docs         850943
# 716   86371567    GitHub         nasa/code-nasa-gov       13133815
# 717   22809619    GitHub      nasa/earthdata-search        2947341
# 718   29485661    GitHub         nasa/edsc-timeline        6109463
# 719  207164226    GitHub  nasa/georef_geocamutilweb       29480027
#
#     manifest_platform                                  manifest_filepath  \
# 0            rubygems                                       Gemfile.lock
# 1                 NPM                                       package.json
# 2                 NPM                                       package.json
# 3               maven                                 tableViews/pom.xml
# 4            rubygems                                       Gemfile.lock
# 5            rubygems                                       Gemfile.lock
# 6                 npm                                       package.json
# 7               maven                          multiColumnTables/pom.xml
# 8               maven                       ImportExportProvider/pom.xml
# 9                 NPM                                       package.json
# 10           rubygems                                       Gemfile.lock
# 11          packagist                                      composer.lock
# 12                NPM                                       package.json
# 13          packagist                                      composer.json
# 14           rubygems                                            Gemfile
# 15           Rubygems                                            Gemfile
# 16                NPM                                       package.json
# 17                NPM                                       package.json
# 18           rubygems                                       Gemfile.lock
# 19           rubygems                                       Gemfile.lock
# 20           rubygems                                            Gemfile
# 21           rubygems                                            Gemfile
# 22                NPM                                       package.json
# 23              maven                                      batik/pom.xml
# 24           rubygems                                       Gemfile.lock
# 25           rubygems                                       Gemfile.lock
# 26           rubygems                                       Gemfile.lock
# 27           Rubygems                                       Gemfile.lock
# 28                NPM                                       package.json
# 29              Bower                                         bower.json
# ..                ...                                                ...
# 690          rubygems                                            Gemfile
# 691          rubygems                                       Gemfile.lock
# 692               NPM                                       package.json
# 693          rubygems                                       Gemfile.lock
# 694          Rubygems                                            Gemfile
# 695          rubygems                                       Gemfile.lock
# 696          rubygems                                       Gemfile.lock
# 697             maven                                      batik/pom.xml
# 698          rubygems                                       Gemfile.lock
# 699          rubygems                                       Gemfile.lock
# 700          rubygems                                       Gemfile.lock
# 701               NPM                                       package.json
# 702          Rubygems                                       Gemfile.lock
# 703          rubygems                                       Gemfile.lock
# 704          rubygems                                       Gemfile.lock
# 705          Rubygems                                       Gemfile.lock
# 706             maven                       ImportExportProvider/pom.xml
# 707               NPM                                       package.json
# 708          rubygems                                       Gemfile.lock
# 709          rubygems                                       Gemfile.lock
# 710          rubygems                                       Gemfile.lock
# 711          Rubygems                                       Gemfile.lock
# 712          Rubygems                                       Gemfile.lock
# 713          rubygems                                       Gemfile.lock
# 714               NPM                                       package.json
# 715          rubygems                                       Gemfile.lock
# 716             Bower                                         bower.json
# 717          Rubygems                                            Gemfile
# 718               NPM                                       package.json
# 719              pypi  geocamUtil/example/submodules/app1/requirement...
#
#     git_branch manifest_kind optional  \
# 0                   lockfile
# 1                   manifest
# 2                   manifest
# 3                   manifest
# 4                   lockfile
# 5                   lockfile
# 6                   manifest
# 7                   manifest
# 8                   manifest
# 9                   manifest
# 10                  lockfile
# 11                  lockfile
# 12                  manifest
# 13                  manifest
# 14                  manifest
# 15                  manifest
# 16                  manifest
# 17                  manifest
# 18                  lockfile
# 19                  lockfile
# 20                  manifest
# 21                  manifest
# 22                  manifest
# 23                  manifest
# 24                  lockfile
# 25                  lockfile
# 26                  lockfile
# 27                  lockfile
# 28                  manifest
# 29                  manifest
# ..         ...           ...      ...
# 690                 manifest
# 691                 lockfile
# 692                 manifest
# 693                 lockfile
# 694                 manifest
# 695                 lockfile
# 696                 lockfile
# 697                 manifest
# 698                 lockfile
# 699                 lockfile
# 700                 lockfile
# 701                 manifest
# 702                 lockfile
# 703                 lockfile
# 704                 lockfile
# 705                 lockfile
# 706                 manifest
# 707                 manifest
# 708                 lockfile
# 709                 lockfile
# 710                 lockfile
# 711                 lockfile
# 712                 lockfile
# 713                 lockfile
# 714                 manifest
# 715                 lockfile
# 716                 manifest
# 717                 manifest
# 718                 manifest
# 719                 manifest
#
#                          dependency_project_name  \
# 0                                        georuby
# 1                                  karma-webpack
# 2                                   babel-loader
# 3                       gov.nasa.arc.mct:mctcore
# 4                                sprockets-rails
# 5                                   compass-core
# 6                                     url-loader
# 7                       gov.nasa.arc.mct:mctcore
# 8    gov.nasa.arc.mct:timeSequenceFeedAggregator
# 9                                      phantomjs
# 10                     rails_serve_static_assets
# 11                               illuminate/view
# 12                                 coffee-loader
# 13                             illuminate/config
# 14                                rails_12factor
# 15                              knockoutjs-rails
# 16                                 coffee-script
# 17                                  style-loader
# 18                                          kgio
# 19                                  em-websocket
# 20                                       webmock
# 21                                       georuby
# 22                                       request
# 23                             xml-apis:xml-apis
# 24                                  activerecord
# 25                          middleman-livereload
# 26                                http_parser.rb
# 27                                          i18n
# 28                                 script-loader
# 29                                 eventemitter3
# ..                                           ...
# 690                                  rspec-rails
# 691                                         sass
# 692                                    phantomjs
# 693                                      builder
# 694                                 therubyracer
# 695                               cucumber-rails
# 696                                      coderay
# 697                          batik:batik-svg-dom
# 698                                     rack-ssl
# 699                                coffee-script
# 700                                        libv8
# 701                                script-loader
# 702                                     whenever
# 703                                activesupport
# 704                                  rest-client
# 705                                       cliver
# 706                     gov.nasa.arc.mct:mctcore
# 707                                coffee-loader
# 708                                     hashdiff
# 709                         coffee-script-source
# 710                                      parslet
# 711                                     railties
# 712                                  rspec-rails
# 713                                        hooks
# 714                                simple-slider
# 715                                         thor
# 716                                    iron-list
# 717                           factory_girl_rails
# 718                                coffee-script
# 719                                       dutest
#
#                 dependency_requirements dependency_kind  dependency_project_id
# 0                                 2.2.1         runtime               205169.0
# 1                                ^1.7.0     development               292395.0
# 2                                ^6.1.0     development               570156.0
# 3               ${mct.platform.version}        provided                    NaN
# 4                                 3.1.1         runtime               254812.0
# 5                                 1.0.1         runtime               190151.0
# 6                                ^0.5.8     development               327327.0
# 7               ${mct.platform.version}         runtime                    NaN
# 8               ${mct.platform.version}        provided                    NaN
# 9                               ^1.9.18     development               301188.0
# 10                                0.0.5         runtime               239700.0
# 11                              v5.4.17         runtime                78054.0
# 12                               ^0.7.2     development               274919.0
# 13                               ~5.4.0         runtime                77807.0
# 14                                 >= 0         runtime               239062.0
# 15                                 >= 0         runtime               217464.0
# 16                              ^1.10.0     development               136813.0
# 17                              ^0.12.3     development               319230.0
# 18                               2.10.0         runtime               216874.0
# 19                                0.5.1         runtime               198285.0
# 20                                 >= 0     development               267353.0
# 21                                 >= 0         runtime               205169.0
# 22                              ^2.69.0         runtime               307050.0
# 23                               1.3.04         runtime               361669.0
# 24                              4.2.7.1         runtime                45651.0
# 25                                3.3.4         runtime               223617.0
# 26                                0.6.0         runtime               211121.0
# 27                                0.7.0         runtime               211498.0
# 28                               ^0.6.1     development               311182.0
# 29                               ^1.2.0         runtime               768109.0
# ..                                  ...             ...                    ...
# 690                                >= 0     development               245284.0
# 691                               3.4.9         runtime               248232.0
# 692                             ^1.9.18     development               301188.0
# 693                               3.0.4         runtime               184983.0
# 694                                >= 0     development               259307.0
# 695                               1.4.0         runtime               192204.0
# 696                               1.1.0         runtime               189521.0
# 697                                 1.6         runtime               416477.0
# 698                               1.3.4         runtime               238657.0
# 699                               2.4.1         runtime               189640.0
# 700                          3.16.14.13         runtime               218875.0
# 701                              ^0.6.1     development               311182.0
# 702                               0.9.2         runtime               267793.0
# 703                             4.2.7.1         runtime                49261.0
# 704                               1.8.0         runtime               242823.0
# 705                               0.3.2         runtime               188951.0
# 706             ${mct.platform.version}         runtime                    NaN
# 707                              ^0.7.2     development               274919.0
# 708                               0.3.0         runtime               208906.0
# 709                              1.10.0         runtime               189646.0
# 710                               1.7.1         runtime               233052.0
# 711                            4.1.14.1         runtime               239833.0
# 712                              2.14.2         runtime               245284.0
# 713                               0.4.0         runtime               210576.0
# 714  loopj/jquery-simple-slider#fa64f59     development               313842.0
# 715                              0.19.1         runtime               259453.0
# 716   PolymerElements/iron-list#^1.3.11         runtime              1261178.0
# 717                                >= 0     development               200115.0
# 718                             ^1.10.0     development               136813.0
# 719                             ==0.2.3         runtime                44251.0
#
# [720 rows x 13 columns]

# %%
import requests

r = requests.get('https://libraries.io/api/github/nasa/repositories?api_key=91f3f771438b366da564093e002a2c61&per_page=200')
names = r.json()
project_names = list(map(lambda x: x['full_name'][5:], names))
project_names
# Out:
# ['openmct',
#  'NASA-3D-Resources',
#  'mct',
#  'earthdata-search',
#  'trick',
#  'isle',
#  'api-docs',
#  'VICAR',
#  'code-nasa-gov',
#  'XPlaneConnect',
#  'apod-api',
#  'Open-Source-Catalog',
#  'osal',
#  'nasa-latex-docs',
#  'CrisisMappingToolkit',
#  'NASTRAN-95',
#  'QuIP',
#  'T-MATS',
#  'DERT',
#  'autodoc',
#  'pvslib',
#  'CFL3D',
#  'Common-Metadata-Repository',
#  'Kodiak',
#  'OpenSPIFe',
#  'kepler-pipeline',
#  'cumulus',
#  'icarous',
#  'RHEAS',
#  'IDF',
#  'fprime',
#  'PyTDA',
#  'ipv6_python',
#  'libSPRITE',
#  'channel-emulator',
#  'astrobee',
#  'astrobot',
#  'dictionaries',
#  'podaacpy',
#  'mmt',
#  'digital-strategy',
#  'PrognosticsAlgorithmLibrary',
#  'CertWare',
#  'data.nasa.gov',
#  'code.nasa.gov_legacy',
#  'PyBlock',
#  'PrognosticsModelLibrary',
#  'SingleDop',
#  'mplStyle',
#  'DAVEtools',
#  'RtRetrievalFramework',
#  'GTM_DesignSim',
#  'DualPol',
#  'PolyCARP',
#  'CCDD',
#  'GFR',
#  'sitepod',
#  'multipath-tcp-tools',
#  'common-mapping-client',
#  'meshNetwork',
#  'WinSURE',
#  'gFTL',
#  'MISR-Toolkit',
#  'CompDam_DGD',
#  'edsc-timeline',
#  'PRECiSA',
#  'WinASSIST',
#  'abaverify',
#  'OpenVSP3Plugin',
#  'kepler-robovetter',
#  'edsc-echoforms',
#  'Open-Gov-Plan-v4',
#  'cmr-metadata-review',
#  'VirtualADAPT',
#  'TrickFMI',
#  'Ctor/framework',
#  'astrobee_android',
#  'data-science-day',
#  'LH2Sim',
#  'cfs_lib',
#  'refine',
#  'SCH',
#  'MM',
#  'nasapress',
#  'aggregate-dictionary',
#  'knife',
#  'MLMCPy',
#  'MINX',
#  'RVLib',
#  'DS',
#  'SBN',
#  'SAFE-DART',
#  'SC',
#  'cFS',
#  'HS',
#  'HK',
#  'RtRetrievalFrameworkDoc',
#  'cumulus-message-adapter',
#  'SROMPy',
#  'georef',
#  'KeplerPORTs',
#  'MAV',
#  'georef_imageregistration',
#  'Kepler-FLTI',
#  'FM',
#  'AGTF30',
#  'MD',
#  'CFS_IO_LIB',
#  'CF',
#  'CCSDS-MAL-API',
#  'CFS_CI',
#  'landslide',
#  'nasapress-companion',
#  'CS',
#  'LC',
#  'cumulus-message-adapter-js',
#  'cumulus-message-adapter-python',
#  'Ctor/documentation',
#  'DON-Federate-HLA2MPC',
#  'cmr-csw',
#  'georef_deploy',
#  'georef_geocamtiepoint',
#  'cmr-opensearch',
#  'PrognosticsMetricsLibrary',
#  'edsc-search-test-config-3',
#  'centerops.jsc.nasa.gov',
#  'edsc-search-test-config-2',
#  'georef_geocamutilweb',
#  'ESPRESSO',
#  'ominas',
#  'CFS-101',
#  'earthdata-search-test-config',
#  'CFS_TO',
#  'Computational-Materials-Miniapp1',
#  'edsc-geo',
#  'FEI',
#  'edsc-widgets']

# %%
# What are the top dependencies used by NASA per platform?
query5 = """
SELECT
  dependency_platform,
  COUNT(*) dependencies,
  APPROX_TOP_COUNT(dependency_name, 3) top_dependencies
FROM
  `bigquery-public-data.libraries_io.dependencies`
WHERE
  project_name IN ({project_names})
  
GROUP BY
  dependency_platform
        """.format(project_names=', '.join('"' + name + '"' for name in project_names))
top_dependecies = library.query_to_pandas_safe(query5, max_gb_scanned=30)
top_dependecies
# Out:
#   dependency_platform  dependencies  \
# 0                Pypi             5
# 1                 NPM           358
# 2            Rubygems          2326
# 3                 Hex             8
# 4                 Npm            42
# 5               NuGet             2
# 6                CRAN             5
#
#                                     top_dependencies
# 0  [{'value': 'webtest', 'count': 3}, {'value': '...
# 1  [{'value': 'mocha', 'count': 28}, {'value': 'm...
# 2  [{'value': 'append_to_line', 'count': 249}, {'...
# 3  [{'value': 'httpoison', 'count': 2}, {'value':...
# 4  [{'value': 'atom-space-pen-views', 'count': 6}...
# 5         [{'value': 'Newtonsoft.Json', 'count': 2}]
# 6  [{'value': 'R', 'count': 2}, {'value': 'stats4...

# %%
# Get a list of unique packages that the given user's repositories list as a dependency. 
# Ordered by frequency of use in those repositories.

req = requests.get('https://libraries.io/api/github/nasa/dependencies?api_key=91f3f771438b366da564093e002a2c61&per_page=586')
names = r.json()

data = pd.DataFrame(names)
list(data)
# Out:
# ['contributions_count',
#  'created_at',
#  'default_branch',
#  'description',
#  'fork',
#  'fork_policy',
#  'forks_count',
#  'full_name',
#  'github_contributions_count',
#  'github_id',
#  'has_audit',
#  'has_changelog',
#  'has_coc',
#  'has_contributing',
#  'has_issues',
#  'has_license',
#  'has_pages',
#  'has_readme',
#  'has_threat_model',
#  'has_wiki',
#  'homepage',
#  'host_domain',
#  'host_type',
#  'keywords',
#  'language',
#  'last_synced_at',
#  'license',
#  'logo_url',
#  'mirror_url',
#  'name',
#  'open_issues_count',
#  'private',
#  'pull_requests_enabled',
#  'pushed_at',
#  'rank',
#  'scm',
#  'size',
#  'source_name',
#  'stargazers_count',
#  'status',
#  'subscribers_count',
#  'updated_at',
#  'uuid']

# %%
data[["full_name","description","forks_count","github_contributions_count","language", "size", "rank"]]
# Out:
#                                  full_name  \
# 0                             nasa/openmct
# 1                   nasa/NASA-3D-Resources
# 2                                 nasa/mct
# 3                    nasa/earthdata-search
# 4                               nasa/trick
# 5                                nasa/isle
# 6                            nasa/api-docs
# 7                               nasa/VICAR
# 8                       nasa/code-nasa-gov
# 9                       nasa/XPlaneConnect
# 10                           nasa/apod-api
# 11                nasa/Open-Source-Catalog
# 12                               nasa/osal
# 13                    nasa/nasa-latex-docs
# 14               nasa/CrisisMappingToolkit
# 15                         nasa/NASTRAN-95
# 16                               nasa/QuIP
# 17                             nasa/T-MATS
# 18                               nasa/DERT
# 19                            nasa/autodoc
# 20                             nasa/pvslib
# 21                              nasa/CFL3D
# 22         nasa/Common-Metadata-Repository
# 23                             nasa/Kodiak
# 24                          nasa/OpenSPIFe
# 25                    nasa/kepler-pipeline
# 26                            nasa/cumulus
# 27                            nasa/icarous
# 28                              nasa/RHEAS
# 29                                nasa/IDF
# ..                                     ...
# 107                        nasa/CFS_IO_LIB
# 108                                nasa/CF
# 109                     nasa/CCSDS-MAL-API
# 110                            nasa/CFS_CI
# 111                         nasa/landslide
# 112               nasa/nasapress-companion
# 113                                nasa/CS
# 114                                nasa/LC
# 115        nasa/cumulus-message-adapter-js
# 116    nasa/cumulus-message-adapter-python
# 117                ReFRACtor/documentation
# 118              nasa/DON-Federate-HLA2MPC
# 119                           nasa/cmr-csw
# 120                     nasa/georef_deploy
# 121             nasa/georef_geocamtiepoint
# 122                    nasa/cmr-opensearch
# 123         nasa/PrognosticsMetricsLibrary
# 124         nasa/edsc-search-test-config-3
# 125            nasa/centerops.jsc.nasa.gov
# 126         nasa/edsc-search-test-config-2
# 127              nasa/georef_geocamutilweb
# 128                          nasa/ESPRESSO
# 129                            nasa/ominas
# 130                           nasa/CFS-101
# 131      nasa/earthdata-search-test-config
# 132                            nasa/CFS_TO
# 133  nasa/Computational-Materials-Miniapp1
# 134                          nasa/edsc-geo
# 135                               nasa/FEI
# 136                      nasa/edsc-widgets
#
#                                            description  forks_count  \
# 0              A web based mission control framework.           635
# 1    Here you'll find a growing collection of 3D mo...          208
# 2    Open MCT has moved to https://github.com/nasa/...          283
# 3    Earthdata Search is a web application develope...          135
# 4    Trick Simulation Environment.  Trick provides ...           95
# 5                                                 None           47
# 6       The API documentation for several NASA APIs.             56
# 7                                                 None           71
# 8    code.nasa.gov site leveraging the Open Source ...           40
# 9    The X-Plane Communications Toolbox is a resear...           85
# 10            Astronomy Picture of the Day API service           41
# 11   contains the NASA open source software catalog...           84
# 12                  Operating System Abstraction Layer           75
# 13                            Official Documentation:            36
# 14                    NASA Ames Crisis Mapping Toolkit           41
# 15                                                None           87
# 16   QuIP provides an interactive environment for c...           30
# 17   An open source thermodynamic modeling package ...           57
# 18   DERT is an open source software tool for explo...           44
# 19   Create Microsoft Documents automatically using...           45
# 20             NASA PVS Library of Formal Developments           31
# 21                                                None           75
# 22                                                None           30
# 23   Library for rigorous verification of non-linea...           26
# 24   The Open Scheduling and Planning Interface for...           39
# 25             Kepler Science Data Processing Pipeline           10
# 26                     Cumulus Framework + Cumulus API           26
# 27   Integrated Configurable Algorithms for Reliabl...           34
# 28      Regional Hydrologic Extremes Assessment System           43
# 29                                                None           37
# ..                                                 ...          ...
# 107                                               None            0
# 108                                               None            1
# 109                                  CCSDS C++ MAL API            4
# 110                                               None            0
# 111                   repo to host landslide front-end            5
# 112  Contains functions and shortcodes used by the ...            1
# 113                                               None            1
# 114                                               None            1
# 115  A library for validating and parsing the Cumul...            4
# 116                                               None            3
# 117             User's guide for compilation and usage            3
# 118                                               None            0
# 119  CMR-CSW is a web application developed by NASA...            2
# 120                                               None            0
# 121                                               None            1
# 122  CMR-OpenSearch is a web application developed ...            3
# 123                                               None            0
# 124                                               None            0
# 125  Code and issues related to centerops.jsc.nasa.gov            5
# 126                                               None            0
# 127                                               None            1
# 128                                               None            0
# 129                                               None            0
# 130                                               None            1
# 131               test repo mimicking earthdata-search            1
# 132                                               None            0
# 133                                               None            0
# 134                                               None            7
# 135                                               None            0
# 136                                               None            6
#
#      github_contributions_count                  language     size  rank
# 0                            22                JavaScript    39643    10
# 1                             2               Mathematica  1998259     6
# 2                            13                      Java     8823     6
# 3                             7                      Ruby   134354     8
# 4                             5                       C++    38582     7
# 5                             2                JavaScript     1069     5
# 6                             3                JavaScript     7317     6
# 7                             1  DIGITAL Command Language   653147     5
# 8                             6                      HTML    29823     5
# 9                             4                         C    19822     7
# 10                            2                    Python       67     5
# 11                            7                      None     1225     6
# 12                            1                         C     6529     6
# 13                            1                       TeX     3797     7
# 14                            5                    Python     1311     7
# 15                            1                   Fortran    87810     4
# 16                            2                         C     5561     5
# 17                            3                      HTML    14887     6
# 18                            2                      Java   388017     5
# 19                            1                      None     5500     5
# 20                            2                    Python    40086     6
# 21                            1                   Fortran     2612     6
# 22                            1                   Clojure    21440     6
# 23                            3                    Python    12563     5
# 24                            2                      Java   140919     5
# 25                            1                         C   171064     5
# 26                           22                JavaScript    68355    10
# 27                            1                       C++    97130     5
# 28                            4                    Python   288700     7
# 29                            1                       C++    29286     6
# ..                          ...                       ...      ...   ...
# 107                           1                      None        0     2
# 108                           1                         C     9414     2
# 109                           1                      None        0     2
# 110                           1                      None        0     2
# 111                           1                      None        8     2
# 112                           1                       PHP        6     2
# 113                           2                         C     4056     2
# 114                           1                         C    12026     2
# 115                           9                JavaScript      125     6
# 116                           9                    Python       71     5
# 117                           1                    Python     1065     4
# 118                           2                      HTML      206     3
# 119                           2                      Ruby     7369     3
# 120                           1                      Ruby      692     3
# 121                           1                    Python     6147     3
# 122                           2                      Ruby    32964     3
# 123                           1                    Matlab       27     2
# 124                           1                      None        0     2
# 125                           1                      None      124     2
# 126                           1                      None        0     2
# 127                           7                    Python     1634     2
# 128                           1                      None        0     2
# 129                           1                      None        0     2
# 130                           1                      None  3106250     2
# 131                           1                      None        0     2
# 132                           1                      None        0     2
# 133                           1                      None        0     2
# 134                           1                      None      124     2
# 135                           0                      None        0     1
# 136                           1                      None      124     0
#
# [137 rows x 7 columns]

# %%
data.describe()
# Out:
#        contributions_count  forks_count  github_contributions_count  \
# count           137.000000   137.000000                  137.000000
# mean              2.423358    24.065693                    2.423358
# std               3.149983    63.883304                    3.149983
# min               0.000000     0.000000                    0.000000
# 25%               1.000000     1.000000                    1.000000
# 50%               1.000000     5.000000                    1.000000
# 75%               2.000000    25.000000                    2.000000
# max              22.000000   635.000000                   22.000000
#
#        open_issues_count        rank          size  stargazers_count  \
# count         137.000000  137.000000  1.370000e+02        137.000000
# mean            5.737226    3.824818  7.603874e+04         98.036496
# std            28.239071    1.810500  3.312781e+05        609.002070
# min             0.000000    0.000000  0.000000e+00          0.000000
# 25%             0.000000    2.000000  2.440000e+02          1.000000
# 50%             0.000000    4.000000  3.797000e+03          6.000000
# 75%             1.000000    5.000000  1.735800e+04         42.000000
# max           295.000000   10.000000  3.106250e+06       6958.000000
#
#        subscribers_count
# count         137.000000
# mean           16.313869
# std            34.926973
# min             1.000000
# 25%             5.000000
# 50%             7.000000
# 75%            14.000000
# max           272.000000

# %%
r = requests.get('https://libraries.io/api/github/nasa/repositories?api_key=91f3f771438b366da564093e002a2c61&per_page=200')
project_names = r.json()
names = list(map(lambda x: x['full_name'], project_names))
names
# Out:
# ['nasa/openmct',
#  'nasa/NASA-3D-Resources',
#  'nasa/mct',
#  'nasa/earthdata-search',
#  'nasa/trick',
#  'nasa/isle',
#  'nasa/api-docs',
#  'nasa/VICAR',
#  'nasa/code-nasa-gov',
#  'nasa/XPlaneConnect',
#  'nasa/apod-api',
#  'nasa/Open-Source-Catalog',
#  'nasa/osal',
#  'nasa/nasa-latex-docs',
#  'nasa/CrisisMappingToolkit',
#  'nasa/NASTRAN-95',
#  'nasa/QuIP',
#  'nasa/T-MATS',
#  'nasa/DERT',
#  'nasa/autodoc',
#  'nasa/pvslib',
#  'nasa/CFL3D',
#  'nasa/Common-Metadata-Repository',
#  'nasa/Kodiak',
#  'nasa/OpenSPIFe',
#  'nasa/kepler-pipeline',
#  'nasa/cumulus',
#  'nasa/icarous',
#  'nasa/RHEAS',
#  'nasa/IDF',
#  'nasa/fprime',
#  'nasa/PyTDA',
#  'nasa/ipv6_python',
#  'nasa/libSPRITE',
#  'nasa/channel-emulator',
#  'nasa/astrobee',
#  'nasa/astrobot',
#  'nasa/dictionaries',
#  'nasa/podaacpy',
#  'nasa/mmt',
#  'nasa/digital-strategy',
#  'nasa/PrognosticsAlgorithmLibrary',
#  'nasa/CertWare',
#  'nasa/data.nasa.gov',
#  'nasa/code.nasa.gov_legacy',
#  'nasa/PyBlock',
#  'nasa/PrognosticsModelLibrary',
#  'nasa/SingleDop',
#  'nasa/mplStyle',
#  'nasa/DAVEtools',
#  'nasa/RtRetrievalFramework',
#  'nasa/GTM_DesignSim',
#  'nasa/DualPol',
#  'nasa/PolyCARP',
#  'nasa/CCDD',
#  'nasa/GFR',
#  'nasa/sitepod',
#  'nasa/multipath-tcp-tools',
#  'nasa/common-mapping-client',
#  'nasa/meshNetwork',
#  'nasa/WinSURE',
#  'nasa/gFTL',
#  'nasa/MISR-Toolkit',
#  'nasa/CompDam_DGD',
#  'nasa/edsc-timeline',
#  'nasa/PRECiSA',
#  'nasa/WinASSIST',
#  'nasa/abaverify',
#  'nasa/OpenVSP3Plugin',
#  'nasa/kepler-robovetter',
#  'nasa/edsc-echoforms',
#  'nasa/Open-Gov-Plan-v4',
#  'nasa/cmr-metadata-review',
#  'nasa/VirtualADAPT',
#  'nasa/TrickFMI',
#  'ReFRACtor/framework',
#  'nasa/astrobee_android',
#  'nasa/data-science-day',
#  'nasa/LH2Sim',
#  'nasa/cfs_lib',
#  'nasa/refine',
#  'nasa/SCH',
#  'nasa/MM',
#  'nasa/nasapress',
#  'nasa/aggregate-dictionary',
#  'nasa/knife',
#  'nasa/MLMCPy',
#  'nasa/MINX',
#  'nasa/RVLib',
#  'nasa/DS',
#  'nasa/SBN',
#  'nasa/SAFE-DART',
#  'nasa/SC',
#  'nasa/cFS',
#  'nasa/HS',
#  'nasa/HK',
#  'nasa/RtRetrievalFrameworkDoc',
#  'nasa/cumulus-message-adapter',
#  'nasa/SROMPy',
#  'nasa/georef',
#  'nasa/KeplerPORTs',
#  'nasa/MAV',
#  'nasa/georef_imageregistration',
#  'nasa/Kepler-FLTI',
#  'nasa/FM',
#  'nasa/AGTF30',
#  'nasa/MD',
#  'nasa/CFS_IO_LIB',
#  'nasa/CF',
#  'nasa/CCSDS-MAL-API',
#  'nasa/CFS_CI',
#  'nasa/landslide',
#  'nasa/nasapress-companion',
#  'nasa/CS',
#  'nasa/LC',
#  'nasa/cumulus-message-adapter-js',
#  'nasa/cumulus-message-adapter-python',
#  'ReFRACtor/documentation',
#  'nasa/DON-Federate-HLA2MPC',
#  'nasa/cmr-csw',
#  'nasa/georef_deploy',
#  'nasa/georef_geocamtiepoint',
#  'nasa/cmr-opensearch',
#  'nasa/PrognosticsMetricsLibrary',
#  'nasa/edsc-search-test-config-3',
#  'nasa/centerops.jsc.nasa.gov',
#  'nasa/edsc-search-test-config-2',
#  'nasa/georef_geocamutilweb',
#  'nasa/ESPRESSO',
#  'nasa/ominas',
#  'nasa/CFS-101',
#  'nasa/earthdata-search-test-config',
#  'nasa/CFS_TO',
#  'nasa/Computational-Materials-Miniapp1',
#  'nasa/edsc-geo',
#  'nasa/FEI',
#  'nasa/edsc-widgets']

# %%
# What are the top dependencies user by NASA per manifest platform?

query6 = """
SELECT
  manifest_platform,
  COUNT(*) dependencies,
  APPROX_TOP_COUNT(dependency_project_name, 5) top_dependencies
FROM
  `bigquery-public-data.libraries_io.repository_dependencies`
WHERE
 repository_name_with_owner IN ({names})
  
GROUP BY
 manifest_platform
        """.format(names=', '.join('"' + name + '"' for name in names))
main_dependecies = library.query_to_pandas_safe(query6, max_gb_scanned=30)
results = pd.DataFrame(main_dependecies)
df_dependencies = pd.DataFrame(results)
df_dependencies
# Out:
#   manifest_platform  dependencies  \
# 0          Rubygems           144
# 1             maven            54
# 2          rubygems           283
# 3               npm            36
# 4               NPM           116
# 5             Bower            31
# 6              PyPI             3
# 7              pypi            35
# 8         packagist            18
#
#                                     top_dependencies
# 0  [{'value': 'jasmine', 'count': 2}, {'value': '...
# 1  [{'value': 'gov.nasa.arc.mct:mctcore', 'count'...
# 2  [{'value': 'therubyracer', 'count': 6}, {'valu...
# 3  [{'value': 'postcss-loader', 'count': 1}, {'va...
# 4  [{'value': 'karma-jasmine', 'count': 4}, {'val...
# 5  [{'value': 'iron-icon', 'count': 1}, {'value':...
# 6  [{'value': 'setuptools', 'count': 1}, {'value'...
# 7  [{'value': 'nose', 'count': 2}, {'value': 'bea...
# 8  [{'value': 'illuminate/config', 'count': 2}, {...

# %%
# Replacing all repetitive manifest platform names to uppercase 

df_dependencies['manifest_platform'] = df_dependencies['manifest_platform'].replace(['npm' , 'pypi', 'rubygems'], ['NPM', 'PyPI', 'Rubygems'])
# df_dependencies

# %%
aggregation_functions = {'manifest_platform': 'first','dependencies': 'sum', 'top_dependencies': 'sum'}
df_new = df_dependencies.groupby(df_dependencies['manifest_platform']).aggregate(aggregation_functions)
joined_data = pd.DataFrame(df_new)
joined_data
# Out:
#                   manifest_platform  dependencies  \
# manifest_platform
# Bower                         Bower            31
# NPM                             NPM           152
# PyPI                           PyPI            38
# Rubygems                   Rubygems           427
# maven                         maven            54
# packagist                 packagist            18
#
#                                                     top_dependencies
# manifest_platform
# Bower              [{'value': 'iron-icon', 'count': 1}, {'value':...
# NPM                [{'value': 'postcss-loader', 'count': 1}, {'va...
# PyPI               [{'value': 'setuptools', 'count': 1}, {'value'...
# Rubygems           [{'value': 'jasmine', 'count': 2}, {'value': '...
# maven              [{'value': 'gov.nasa.arc.mct:mctcore', 'count'...
# packagist          [{'value': 'illuminate/config', 'count': 2}, {...

# %%
import matplotlib
joined_data.dependencies.hist(bins=6)

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = joined_data['manifest_platform']
sizes = joined_data['dependencies']
explode = (0, 0, 0, 0.1, 0, 0) 

plt.rcParams['font.size'] = 15.0
fig1, ax1 = plt.subplots(figsize=(20,15))
ax1.pie(sizes, labels=labels, explode=explode, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')

plt.show()

# %%
# For each repository on that list, see if count of dependencies > 0
query7 = """
SELECT
  repository_name_with_owner,
  COUNT(*) dependencies,
  APPROX_TOP_COUNT(dependency_project_name, 5) top_dependencies
FROM
  `bigquery-public-data.libraries_io.repository_dependencies`
WHERE
 repository_name_with_owner IN ({names})
  
GROUP BY
 repository_name_with_owner
        """.format(names=', '.join('"' + name + '"' for name in names))
dependency_count_per_project = library.query_to_pandas_safe(query7, max_gb_scanned=30)
dep = pd.DataFrame(dependency_count_per_project)

# %%
r = requests.get('https://libraries.io/api/NPM/openmct/contributors?api_key=91f3f771438b366da564093e002a2c61&per_page=200')
contributors = r.json()
contributors
# Out:
# [{'github_id': '1117290',
#   'login': 'tarikozket',
#   'user_type': 'User',
#   'created_at': '2015-01-28T14:04:34.005Z',
#   'updated_at': '2018-12-29T02:44:23.892Z',
#   'name': 'Tarik',
#   'company': None,
#   'blog': 'http://ozket.net',
#   'location': 'San Francisco Bay Area',
#   'hidden': False,
#   'last_synced_at': '2016-12-22T20:01:43.699Z',
#   'email': 'tarik@ozket.net',
#   'bio': None,
#   'followers': 15,
#   'following': 23,
#   'uuid': '1117290',
#   'host_type': 'GitHub'},
#  {'github_id': '2753855',
#   'login': 'jesusprubio',
#   'user_type': 'User',
#   'created_at': '2015-01-28T15:11:39.383Z',
#   'updated_at': '2018-06-30T06:33:13.270Z',
#   'name': 'Jesús Pérez',
#   'company': '@IBMResearch ',
#   'blog': 'https://twitter.com/jesusprubio',
#   'location': 'A Coruña',
#   'hidden': False,
#   'last_synced_at': '2016-06-13T10:40:04.687Z',
#   'email': 'jesusprubio@gmail.com',
#   'bio': None,
#   'followers': 72,
#   'following': 60,
#   'uuid': '2753855',
#   'host_type': 'GitHub'},
#  {'github_id': '1105608',
#   'login': 'ZachMoreno',
#   'user_type': 'User',
#   'created_at': '2015-02-03T01:26:18.466Z',
#   'updated_at': '2018-02-03T04:06:01.271Z',
#   'name': 'Zachariah Moreno',
#   'company': '@SquadCast ',
#   'blog': '',
#   'location': 'Alameda, California',
#   'hidden': False,
#   'last_synced_at': '2016-12-30T08:03:11.575Z',
#   'email': 'xachmoreno@gmail.com',
#   'bio': 'cultivating creative collaboration',
#   'followers': 22,
#   'following': 31,
#   'uuid': '1105608',
#   'host_type': 'GitHub'},
#  {'github_id': '5647344',
#   'login': 'charbelrami',
#   'user_type': 'User',
#   'created_at': '2015-02-03T01:31:53.672Z',
#   'updated_at': '2016-06-13T10:39:44.074Z',
#   'name': 'Charbel',
#   'company': None,
#   'blog': 'https://twitter.com/charbelrami',
#   'location': None,
#   'hidden': False,
#   'last_synced_at': '2016-06-13T10:39:44.047Z',
#   'email': None,
#   'bio': None,
#   'followers': 21,
#   'following': 52,
#   'uuid': '5647344',
#   'host_type': 'GitHub'},
#  {'github_id': '1322923',
#   'login': 'danielpacak',
#   'user_type': 'User',
#   'created_at': '2015-02-17T02:15:21.646Z',
#   'updated_at': '2017-02-06T01:05:27.796Z',
#   'name': 'Daniel Pacak',
#   'company': 'SOFTWARE CLINIC',
#   'blog': 'http://pl.linkedin.com/in/pacakdaniel',
#   'location': 'Grójec, Poland',
#   'hidden': False,
#   'last_synced_at': '2017-02-06T01:05:27.727Z',
#   'email': 'pacak.daniel@gmail.com',
#   'bio': None,
#   'followers': 35,
#   'following': 115,
#   'uuid': '1322923',
#   'host_type': 'GitHub'},
#  {'github_id': '226503',
#   'login': 'larkin',
#   'user_type': 'User',
#   'created_at': '2015-03-20T04:37:21.482Z',
#   'updated_at': '2016-04-18T10:31:17.414Z',
#   'name': 'Pete Richards',
#   'company': None,
#   'blog': 'pete-richards.com',
#   'location': None,
#   'hidden': False,
#   'last_synced_at': '2016-04-18T10:31:17.342Z',
#   'email': None,
#   'bio': None,
#   'followers': None,
#   'following': None,
#   'uuid': '226503',
#   'host_type': 'GitHub'},
#  {'github_id': '5229481',
#   'login': 'aterribili',
#   'user_type': 'User',
#   'created_at': '2015-05-31T09:01:25.115Z',
#   'updated_at': '2017-06-12T22:29:52.014Z',
#   'name': 'Abner Terribili',
#   'company': '@elo7 ',
#   'blog': 'aterribili.github.io/blog',
#   'location': 'Brazil',
#   'hidden': False,
#   'last_synced_at': '2017-03-04T17:04:05.049Z',
#   'email': 'abner.terribili@gmail.com',
#   'bio': "I'm developer at Elo7, cyclist and trying to save the world.",
#   'followers': None,
#   'following': None,
#   'uuid': '5229481',
#   'host_type': 'GitHub'},
#  {'github_id': '1685764',
#   'login': 'VWoeltjen',
#   'user_type': 'User',
#   'created_at': '2015-06-28T19:55:33.977Z',
#   'updated_at': '2019-03-07T13:11:27.367Z',
#   'name': 'Victory F.X.',
#   'company': 'Humans like you',
#   'blog': 'https://liberapay.com/VictoryFX',
#   'location': 'San Francisco, CA',
#   'hidden': False,
#   'last_synced_at': '2016-04-18T11:10:16.255Z',
#   'email': None,
#   'bio': 'Too weird to be queer, too alien for NASA. Plausibly human.',
#   'followers': None,
#   'following': None,
#   'uuid': '1685764',
#   'host_type': 'GitHub'},
#  {'github_id': '1056412',
#   'login': 'charlesh88',
#   'user_type': 'User',
#   'created_at': '2015-06-28T20:33:55.276Z',
#   'updated_at': '2016-04-18T11:10:59.812Z',
#   'name': 'Charles Hacskaylo',
#   'company': 'NASA',
#   'blog': None,
#   'location': 'United States',
#   'hidden': False,
#   'last_synced_at': '2016-04-18T11:10:59.792Z',
#   'email': None,
#   'bio': None,
#   'followers': None,
#   'following': None,
#   'uuid': '1056412',
#   'host_type': 'GitHub'},
#  {'github_id': '4096238',
#   'login': 'brianwyu',
#   'user_type': 'User',
#   'created_at': '2015-06-28T20:33:55.384Z',
#   'updated_at': '2017-02-07T06:06:38.204Z',
#   'name': None,
#   'company': None,
#   'blog': None,
#   'location': None,
#   'hidden': False,
#   'last_synced_at': '2017-02-07T06:06:37.372Z',
#   'email': None,
#   'bio': None,
#   'followers': None,
#   'following': None,
#   'uuid': '4096238',
#   'host_type': 'GitHub'},
#  {'github_id': '8016166',
#   'login': 'shivamndave',
#   'user_type': 'User',
#   'created_at': '2015-06-28T20:33:55.613Z',
#   'updated_at': '2016-04-18T11:11:02.557Z',
#   'name': 'Shivam Dave',
#   'company': None,
#   'blog': None,
#   'location': None,
#   'hidden': False,
#   'last_synced_at': '2016-04-18T11:11:02.531Z',
#   'email': None,
#   'bio': None,
#   'followers': None,
#   'following': None,
#   'uuid': '8016166',
#   'host_type': 'GitHub'},
#  {'github_id': '2347849',
#   'login': 'slhale',
#   'user_type': 'User',
#   'created_at': '2015-06-28T20:33:55.687Z',
#   'updated_at': '2017-08-04T22:24:49.579Z',
#   'name': None,
#   'company': None,
#   'blog': 'https://www.linkedin.com/in/slhale',
#   'location': 'Harvey Mudd College',
#   'hidden': False,
#   'last_synced_at': '2017-08-04T22:24:49.187Z',
#   'email': 'shale@hmc.edu',
#   'bio': None,
#   'followers': None,
#   'following': None,
#   'uuid': '2347849',
#   'host_type': 'GitHub'},
#  {'github_id': '5050074',
#   'login': 'BogdanAlexandru',
#   'user_type': 'User',
#   'created_at': '2015-06-28T20:59:18.380Z',
#   'updated_at': '2017-08-05T02:24:33.385Z',
#   'name': 'Bogdan Alexandru Marginean',
#   'company': None,
#   'blog': '',
#   'location': 'Romania',
#   'hidden': False,
#   'last_synced_at': '2017-08-05T02:24:32.754Z',
#   'email': None,
#   'bio': None,
#   'followers': None,
#   'following': None,
#   'uuid': '5050074',
#   'host_type': 'GitHub'},
#  {'github_id': '3154089',
#   'login': 'pacozaa',
#   'user_type': 'User',
#   'created_at': '2015-08-28T02:05:06.726Z',
#   'updated_at': '2017-07-11T16:53:36.466Z',
#   'name': 'pacozaa',
#   'company': None,
#   'blog': '',
#   'location': 'Thailand',
#   'hidden': False,
#   'last_synced_at': '2017-04-15T03:28:54.136Z',
#   'email': 'pacosarin@gmail.com',
#   'bio': None,
#   'followers': None,
#   'following': None,
#   'uuid': '3154089',
#   'host_type': 'GitHub'},
#  {'github_id': '1330721',
#   'login': 'smirecki',
#   'user_type': 'User',
#   'created_at': '2015-10-06T01:05:46.258Z',
#   'updated_at': '2016-04-18T11:20:29.870Z',
#   'name': 'smirecki',
#   'company': None,
#   'blog': None,
#   'location': 'United States',
#   'hidden': False,
#   'last_synced_at': '2016-04-18T11:20:29.848Z',
#   'email': None,
#   'bio': None,
#   'followers': None,
#   'following': None,
#   'uuid': '1330721',
#   'host_type': 'GitHub'},
#  {'github_id': '4215777',
#   'login': 'akhenry',
#   'user_type': 'User',
#   'created_at': '2015-10-24T02:17:40.212Z',
#   'updated_at': '2016-04-14T11:58:00.211Z',
#   'name': 'Andrew Henry',
#   'company': None,
#   'blog': None,
#   'location': None,
#   'hidden': False,
#   'last_synced_at': '2016-04-14T11:58:00.190Z',
#   'email': None,
#   'bio': None,
#   'followers': None,
#   'following': None,
#   'uuid': '4215777',
#   'host_type': 'GitHub'},
#  {'github_id': '15857322',
#   'login': 'medinae',
#   'user_type': 'User',
#   'created_at': '2015-11-15T14:20:10.385Z',
#   'updated_at': '2018-02-28T18:42:49.018Z',
#   'name': 'AbdelKader Bouadjadja ',
#   'company': '@aptushealth ',
#   'blog': 'https://connect.sensiolabs.com/profile/medinae',
#   'location': 'Paris',
#   'hidden': False,
#   'last_synced_at': '2016-04-04T18:48:42.110Z',
#   'email': None,
#   'bio': 'SensioLabs Symfony 3 Certified Expert Developer | "Always leave the campground cleaner than you found it"\r\n\r\n',
#   'followers': None,
#   'following': None,
#   'uuid': '15857322',
#   'host_type': 'GitHub'},
#  {'github_id': '12648587',
#   'login': 'dhrubomoy',
#   'user_type': 'User',
#   'created_at': '2015-11-30T03:55:08.384Z',
#   'updated_at': '2017-07-05T00:07:51.894Z',
#   'name': 'Dhrubomoy Das Gupta',
#   'company': '@qlik-trial ',
#   'blog': 'https://www.linkedin.com/in/dhrubomoy-das-gupta-18b2709a/',
#   'location': 'Ottawa, ON',
#   'hidden': False,
#   'last_synced_at': '2016-04-02T08:43:41.634Z',
#   'email': None,
#   'bio': 'Currently pursuing undergraduate in Software Engineering at Carleton University, Ottawa, Canada.',
#   'followers': None,
#   'following': None,
#   'uuid': '12648587',
#   'host_type': 'GitHub'},
#  {'github_id': '10148659',
#   'login': 'vankessel',
#   'user_type': 'User',
#   'created_at': '2015-12-14T20:51:21.496Z',
#   'updated_at': '2016-03-08T14:43:54.216Z',
#   'name': 'Kevin Van Kessel',
#   'company': None,
#   'blog': 'http://vankessel.ca',
#   'location': None,
#   'hidden': False,
#   'last_synced_at': '2016-03-08T14:43:54.213Z',
#   'email': None,
#   'bio': None,
#   'followers': None,
#   'following': None,
#   'uuid': '10148659',
#   'host_type': 'GitHub'},
#  {'github_id': '2712414',
#   'login': 'TypicalFooBar',
#   'user_type': 'User',
#   'created_at': '2016-01-27T05:50:19.094Z',
#   'updated_at': '2018-04-21T21:25:01.904Z',
#   'name': 'Derek Webb',
#   'company': None,
#   'blog': 'http://derekwebb.us',
#   'location': None,
#   'hidden': False,
#   'last_synced_at': '2018-04-21T21:24:56.922Z',
#   'email': None,
#   'bio': None,
#   'followers': None,
#   'following': None,
#   'uuid': '2712414',
#   'host_type': 'GitHub'},
#  {'github_id': '3417997',
#   'login': 'raoulsullivan',
#   'user_type': 'User',
#   'created_at': '2016-04-18T00:39:05.175Z',
#   'updated_at': '2017-12-10T22:35:07.265Z',
#   'name': 'Stephen Raoul Sullivan',
#   'company': 'Beyond Spreadsheets Ltd',
#   'blog': 'http://www.beyondspreadsheets.co.uk',
#   'location': 'United Kingdom',
#   'hidden': False,
#   'last_synced_at': '2016-04-18T00:41:47.564Z',
#   'email': 'stephen@beyondspreadsheets.co.uk',
#   'bio': None,
#   'followers': None,
#   'following': None,
#   'uuid': '3417997',
#   'host_type': 'GitHub'},
#  {'github_id': '15916735',
#   'login': 'mockingjamie',
#   'user_type': 'User',
#   'created_at': '2016-06-04T22:09:33.094Z',
#   'updated_at': '2016-06-04T22:09:36.506Z',
#   'name': None,
#   'company': None,
#   'blog': None,
#   'location': None,
#   'hidden': False,
#   'last_synced_at': '2016-06-04T22:09:36.486Z',
#   'email': None,
#   'bio': None,
#   'followers': None,
#   'following': None,
#   'uuid': '15916735',
#   'host_type': 'GitHub'}]

# %%
# Query all the package managers per project
query8 = """
SELECT  DISTINCT 
  repository_name_with_owner,
  manifest_platform
FROM
  `bigquery-public-data.libraries_io.repository_dependencies`
WHERE
 repository_name_with_owner IN ({names})
  
ORDER BY
  repository_name_with_owner DESC, manifest_platform
        """.format(names=', '.join('"' + name + '"' for name in names))
project = library.query_to_pandas_safe(query8, max_gb_scanned=30)
dependency_mgt_per_project = pd.DataFrame(project)
# Converting data frame to a dictionary
dict_per_project = pd.DataFrame.to_dict(dependency_mgt_per_project)
#dict_per_project

# %%
listOfDicts = dict_per_project['repository_name_with_owner']
fixer = dict_per_project['manifest_platform']

# %%
# Convert and create a list of tuples
dict2 = list(((listOfDicts[key], value) for (key, value) in fixer.items()))

# Create a list of names and the create a dictionary removing "nasa/" from project names
nam = list(map(lambda x: x[0][5:], dict2))
dictOfWords = { i : nam[i] for i in range(0, len(nam) ) }

# Create a list of tuples
dict1 = list(((dictOfWords[key], value) for (key, value) in fixer.items()))

# Convert tuple to a dictionary
def Convert(dict1, di): 
    for a, b in dict1: 
        di.setdefault(a, []).append(b) 
    return di 
      
# Driver Code     
dictionary = {} 
dic = Convert(dict1, dictionary)
print(dic)
# Out:
# {'openmct': ['Bower', 'NPM'], 'nasapress': ['npm', 'packagist'], 'mct': ['maven'], 'georef_geocamutilweb': ['pypi'], 'edsc-timeline': ['NPM'], 'edsc-echoforms': ['NPM'], 'earthdata-search': ['NPM', 'Rubygems'], 'dictionaries': ['pypi'], 'code-nasa-gov': ['Bower'], 'cmr-opensearch': ['rubygems'], 'cmr-csw': ['rubygems'], 'astrobot': ['NPM'], 'apod-api': ['pypi'], 'api-docs': ['rubygems'], 'RtRetrievalFramework': ['pypi'], 'RHEAS': ['PyPI'], 'PyBlock': ['pypi'], 'DualPol': ['pypi'], 'CrisisMappingToolkit': ['PyPI']}

# %%
not_trackable_projects = []
new_array = []

for key, value in dic.items():
    for entry in value:
        url = f'https://libraries.io/api/{entry}/{key}/contributors?api_key=91f3f771438b366da564093e002a2c61'
        r = requests.get(url)
        if r.status_code == 404:
            not_trackable_projects.append((entry, key))
        else:
            contributors = r.json()
            new_array.append(contributors)
print(new_array)            
print(not_trackable_projects)
# Out:
# [[{'github_id': '1117290', 'login': 'tarikozket', 'user_type': 'User', 'created_at': '2015-01-28T14:04:34.005Z', 'updated_at': '2018-12-29T02:44:23.892Z', 'name': 'Tarik', 'company': None, 'blog': 'http://ozket.net', 'location': 'San Francisco Bay Area', 'hidden': False, 'last_synced_at': '2016-12-22T20:01:43.699Z', 'email': 'tarik@ozket.net', 'bio': None, 'followers': 15, 'following': 23, 'uuid': '1117290', 'host_type': 'GitHub'}, {'github_id': '2753855', 'login': 'jesusprubio', 'user_type': 'User', 'created_at': '2015-01-28T15:11:39.383Z', 'updated_at': '2018-06-30T06:33:13.270Z', 'name': 'Jesús Pérez', 'company': '@IBMResearch ', 'blog': 'https://twitter.com/jesusprubio', 'location': 'A Coruña', 'hidden': False, 'last_synced_at': '2016-06-13T10:40:04.687Z', 'email': 'jesusprubio@gmail.com', 'bio': None, 'followers': 72, 'following': 60, 'uuid': '2753855', 'host_type': 'GitHub'}, {'github_id': '1105608', 'login': 'ZachMoreno', 'user_type': 'User', 'created_at': '2015-02-03T01:26:18.466Z', 'updated_at': '2018-02-03T04:06:01.271Z', 'name': 'Zachariah Moreno', 'company': '@SquadCast ', 'blog': '', 'location': 'Alameda, California', 'hidden': False, 'last_synced_at': '2016-12-30T08:03:11.575Z', 'email': 'xachmoreno@gmail.com', 'bio': 'cultivating creative collaboration', 'followers': 22, 'following': 31, 'uuid': '1105608', 'host_type': 'GitHub'}, {'github_id': '5647344', 'login': 'charbelrami', 'user_type': 'User', 'created_at': '2015-02-03T01:31:53.672Z', 'updated_at': '2016-06-13T10:39:44.074Z', 'name': 'Charbel', 'company': None, 'blog': 'https://twitter.com/charbelrami', 'location': None, 'hidden': False, 'last_synced_at': '2016-06-13T10:39:44.047Z', 'email': None, 'bio': None, 'followers': 21, 'following': 52, 'uuid': '5647344', 'host_type': 'GitHub'}, {'github_id': '1322923', 'login': 'danielpacak', 'user_type': 'User', 'created_at': '2015-02-17T02:15:21.646Z', 'updated_at': '2017-02-06T01:05:27.796Z', 'name': 'Daniel Pacak', 'company': 'SOFTWARE CLINIC', 'blog': 'http://pl.linkedin.com/in/pacakdaniel', 'location': 'Grójec, Poland', 'hidden': False, 'last_synced_at': '2017-02-06T01:05:27.727Z', 'email': 'pacak.daniel@gmail.com', 'bio': None, 'followers': 35, 'following': 115, 'uuid': '1322923', 'host_type': 'GitHub'}, {'github_id': '226503', 'login': 'larkin', 'user_type': 'User', 'created_at': '2015-03-20T04:37:21.482Z', 'updated_at': '2016-04-18T10:31:17.414Z', 'name': 'Pete Richards', 'company': None, 'blog': 'pete-richards.com', 'location': None, 'hidden': False, 'last_synced_at': '2016-04-18T10:31:17.342Z', 'email': None, 'bio': None, 'followers': None, 'following': None, 'uuid': '226503', 'host_type': 'GitHub'}, {'github_id': '5229481', 'login': 'aterribili', 'user_type': 'User', 'created_at': '2015-05-31T09:01:25.115Z', 'updated_at': '2017-06-12T22:29:52.014Z', 'name': 'Abner Terribili', 'company': '@elo7 ', 'blog': 'aterribili.github.io/blog', 'location': 'Brazil', 'hidden': False, 'last_synced_at': '2017-03-04T17:04:05.049Z', 'email': 'abner.terribili@gmail.com', 'bio': "I'm developer at Elo7, cyclist and trying to save the world.", 'followers': None, 'following': None, 'uuid': '5229481', 'host_type': 'GitHub'}, {'github_id': '1685764', 'login': 'VWoeltjen', 'user_type': 'User', 'created_at': '2015-06-28T19:55:33.977Z', 'updated_at': '2019-03-07T13:11:27.367Z', 'name': 'Victory F.X.', 'company': 'Humans like you', 'blog': 'https://liberapay.com/VictoryFX', 'location': 'San Francisco, CA', 'hidden': False, 'last_synced_at': '2016-04-18T11:10:16.255Z', 'email': None, 'bio': 'Too weird to be queer, too alien for NASA. Plausibly human.', 'followers': None, 'following': None, 'uuid': '1685764', 'host_type': 'GitHub'}, {'github_id': '1056412', 'login': 'charlesh88', 'user_type': 'User', 'created_at': '2015-06-28T20:33:55.276Z', 'updated_at': '2016-04-18T11:10:59.812Z', 'name': 'Charles Hacskaylo', 'company': 'NASA', 'blog': None, 'location': 'United States', 'hidden': False, 'last_synced_at': '2016-04-18T11:10:59.792Z', ...
# [('Bower', 'openmct'), ('npm', 'nasapress'), ('packagist', 'nasapress'), ('maven', 'mct'), ('pypi', 'georef_geocamutilweb'), ('NPM', 'edsc-timeline'), ('NPM', 'edsc-echoforms'), ('NPM', 'earthdata-search'), ('Rubygems', 'earthdata-search'), ('Bower', 'code-nasa-gov'), ('rubygems', 'cmr-opensearch'), ('rubygems', 'cmr-csw'), ('NPM', 'astrobot'), ('pypi', 'apod-api'), ('rubygems', 'api-docs'), ('pypi', 'RtRetrievalFramework'), ('PyPI', 'RHEAS'), ('pypi', 'DualPol'), ('PyPI', 'CrisisMappingToolkit')]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
from sklearn.cluster import AgglomerativeClustering
from sklearn.feature_extraction.text import CountVectorizer
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler

import sklearn.metrics as sm
from sklearn.metrics import confusion_matrix, classification_report

# %%
from sklearn.decomposition import TruncatedSVD

# SVD represent documents and terms in vectors 
svd_model = TruncatedSVD(n_components=20, algorithm='randomized', n_iter=100, random_state=122)

svd_model.fit(X)

len(svd_model.components_)
# Out:
# 20

# %%
terms = vectorizer.get_feature_names()

for i, comp in enumerate(svd_model.components_):
    terms_comp = zip(terms, comp)
    sorted_terms = sorted(terms_comp, key= lambda x:x[1], reverse=True)[:7]
    print("Topic "+str(i)+": ")
    for t in sorted_terms:
        print(t[0])
        print(" ")
# Out:
# Topic 0:
# uuid
#
# github_contributions_count
#
# open_issues_count
#
# host_domain
#
# has_readme
#
# last_synced_at
#
# scm
#
# Topic 1:
# source_name
#
# has_pages
#
# host_domain
#
# license
#
# language
#
# github_contributions_count
#
# has_wiki
#
# Topic 2:
# name
#
# pushed_at
#
# has_contributing
#
# uuid
#
# keywords
#
# license
#
# stargazers_count
#
# Topic 3:
# logo_url
#
# forks_count
#
# fork_policy
#
# full_name
#
# has_coc
#
# description
#
# has_changelog
#
# Topic 4:
# has_readme
#
# created_at
#
# status
#
# scm
#
# homepage
#
# fork_policy
#
# forks_count
#
# Topic 5:
# last_synced_at
#
# has_wiki
#
# fork
#
# has_pages
#
# created_at
#
# host_domain
#
# status
#
# Topic 6:
# has_pages
#
# updated_at
#
# uuid
#
# subscribers_count
#
# default_branch
#
# full_name
#
# logo_url
#
# Topic 7:
# has_contributing
#
# subscribers_count
#
# created_at
#
# has_readme
#
# size
#
# last_synced_at
#
# keywords
#
# Topic 8:
# has_audit
#
# subscribers_count
#
# language
#
# description
#
# license
#
# private
#
# has_issues
#
# Topic 9:
# rank
#
# name
#
# has_issues
#
# host_domain
#
# fork
#
# description
#
# default_branch
#
# Topic 10:
# pull_requests_enabled
#
# rank
#
# scm
#
# status
#
# name
#
# has_pages
#
# has_coc
#
# Topic 11:
# forks_count
#
# mirror_url
#
# size
#
# description
#
# has_pages
#
# stargazers_count
#
# license
#
# Topic 12:
# keywords
#
# rank
#
# fork
#
# default_branch
#
# stargazers_count
#
# open_issues_count
#
# host_type
#
# Topic 13:
# private
#
# homepage
#
# size
#
# license
#
# has_pages
#
# keywords
#
# status
#
# Topic 14:
# has_readme
#
# has_coc
#
# language
#
# has_pages
#
# status
#
# stargazers_count
#
# has_contributing
#
# Topic 15:
# open_issues_count
#
# name
#
# updated_at
#
# logo_url
#
# has_coc
#
# has_pages
#
# description
#
# Topic 16:
# private
#
# host_type
#
# has_pages
#
# has_contributing
#
# uuid
#
# status
#
# updated_at
#
# Topic 17:
# fork_policy
#
# description
#
# created_at
#
# has_coc
#
# pushed_at
#
# size
#
# stargazers_count
#
# Topic 18:
# language
#
# fork_policy
#
# subscribers_count
#
# mirror_url
#
# host_domain
#
# name
#
# host_type
#
# Topic 19:
# contributions_count
#
# github_contributions_count
#
# default_branch
#
# full_name
#
# logo_url
#
# source_name
#
# created_at

# %%
scaler = StandardScaler()

scaler.fit(data[["forks_count","github_contributions_count", "size", "rank", "contributions_count", "stargazers_count", "subscribers_count"]])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
# Use scaler.transform() on the raw_data and store the results below
scaled_data = scaler.transform(data[["forks_count","github_contributions_count", "size", "rank", "contributions_count", "stargazers_count", "subscribers_count"]])
k_means = KMeans(n_clusters=6)

# Fit the k_means object to the scaled data, and store the results it returns below
output = k_means.fit(scaled_data)

centroids = output.cluster_centers_
scaled_unique_labels = 6
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.

# %%
from itertools import permutations

def _create_array_of_feature_tuples(DATA_SHAPE):
    """ Helper function that inputs integer representing number of columns in dataset 
    and outputs iterable NumPy array of tuples holding dataset feature indices. """
    return [permutation for permutation in permutations(range(DATA_SHAPE), 2)]

# %%
def _produce_cluster_on_subplot(feature_index_pair, subplot, centroids, unique_labels):
    """ Helper function that inputs tuple of indices for specific feature pair and MatPlotLib subplot object
    and outputs appropriate scatterplot of K-Means feature clusters over subplot. """
    col_index1, col_index2 = feature_index_pair[0], feature_index_pair[1]
    subplot.scatter(scaled_data[:, col_index1], scaled_data[:, col_index2], c=unique_labels, cmap="viridis")
    subplot.set_xlabel("FEATURE {}".format(col_index1 + 1))
    subplot.set_ylabel("FEATURE {}".format(col_index2 + 1))
    subplot.scatter(centroids[:, col_index1], centroids[:, col_index2], c="black", s=200, alpha=0.5)
    return

# %%
# the ':,' gets us all 137 rows of data, while the '1' tells us to only get the data in the first column for each row. 
plt.figure('6 Cluster K-Means')
plt.scatter(scaled_data[:, 1], scaled_data[:, 2], c=output.labels_)

# %%
plt.scatter(scaled_data[:, 2], scaled_data[:, 2], c=output.labels_)

# %%
plt.scatter(scaled_data[:, 0], scaled_data[:, 2], c=output.labels_)

# %%
plt.scatter(scaled_data[:, 3], scaled_data[:, 2], c=output.labels_)
plt.scatter(scaled_data[:, 3], scaled_data[:, 3], c=output.labels_)

# %%
plt.scatter(scaled_data[:, 0], scaled_data[:, 0], c=output.labels_)
plt.scatter(scaled_data[:, 0], scaled_data[:, 1], c=output.labels_)
plt.scatter(scaled_data[:, 0], scaled_data[:, 2], c=output.labels_)
plt.scatter(scaled_data[:, 0], scaled_data[:, 3], c=output.labels_)

# %%
plt.scatter(scaled_data[:, 1], scaled_data[:, 0], c=output.labels_)
plt.scatter(scaled_data[:, 1], scaled_data[:, 1], c=output.labels_)
plt.scatter(scaled_data[:, 1], scaled_data[:, 2], c=output.labels_)
plt.scatter(scaled_data[:, 1], scaled_data[:, 3], c=output.labels_)

# %%
plt.scatter(scaled_data[:, 2], scaled_data[:, 0], c=output.labels_)
plt.scatter(scaled_data[:, 2], scaled_data[:, 1], c=output.labels_)
plt.scatter(scaled_data[:, 2], scaled_data[:, 2], c=output.labels_)
plt.scatter(scaled_data[:, 2], scaled_data[:, 3], c=output.labels_)

# %%
from sklearn.decomposition import PCA

pca = PCA()

# call pca.fit() on the data stored in 'scaled_data'.
pca.fit(scaled_data)

# Call pca.transform() on 'scaled_data' and store the results below.  
pca_data = pca.transform(scaled_data)

# When you initialize the object below, make sure 'n_cluster=6'
pca_k_means = KMeans(n_clusters=6)

# Fit the pca_k_means object to the data in 'pca_data'.
pca_k_means.fit(pca_data)

# Principal components in pca_data. 

plt.figure('6 Cluster K-Means')
plt.scatter(scaled_data[:, 1], scaled_data[:, 2], c=output.labels_)

# %%
variance = pca.explained_variance_ratio_

# Enumerate through pca.explained_variance_ratio_ to see the amount of variance captured by each Principal Component
for ind, var in enumerate(variance):
    print("Explained Variance for Principal Component {}: {}".format(ind, var))
# Out:
# Explained Variance for Principal Component 0: 0.6039224888102548
# Explained Variance for Principal Component 1: 0.1705081195767488
# Explained Variance for Principal Component 2: 0.1119164655473214
# Explained Variance for Principal Component 3: 0.08574781308339155
# Explained Variance for Principal Component 4: 0.024752007757016397
# Explained Variance for Principal Component 5: 0.0031531052252671463
# Explained Variance for Principal Component 6: 8.775436170959195e-34
